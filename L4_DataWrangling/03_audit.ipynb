# %%
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint

# %% [markdown]
# - audit the OSMFILE and change the variable 'mapping' to reflect the changes needed to fix
#     the unexpected street types to the appropriate ones in the expected list.
#     You have to add mappings only for the actual problems you find in this OSMFILE,
#     not a generalized solution, since that may and will depend on the particular area you are auditing.
# - write the update_name function, to actually fix the street name.
#     The function takes a string with street name as an argument and should return the fixed name

# %%
OSMFILE = "cuxhaven_sample_50.osm"
#street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)
street_type_re = re.compile(r'.*', re.IGNORECASE)

#expected = ["Straße", "Weg", "Stieg", "Gang", "Ring", "Chaussee"]

# UPDATE THIS VARIABLE
streetmapping = { "Str.": "Straße",
            "KIefhorst": "Kiefhorst",
            "Rd.": "Road"
            }


def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        #if street_type not in expected:
        street_types[street_type].add(street_name)


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types

#pprint.pprint(dict(audit(OSMFILE))) # print the existing names

def update_name(name, streetmapping):
    m = street_type_re.search(name)
    better_name = name
    if m:
        better_street_type = streetmapping[m.group()]
        better_name = street_type_re.sub(better_street_type, name)
    return better_name

def update_name_german(name, streetmapping):
    better_name_german = name
    if name in streetmapping:
        better_name_german = streetmapping[name]
    return better_name_german

# %%
pprint.pprint(dict(audit(OSMFILE))) # print the existing names
# Out:
# {u'Abbestra\xdfe': set([u'Abbestra\xdfe']),
#  u'Abla\xdfer Stra\xdfe': set([u'Abla\xdfer Stra\xdfe']),
#  'Abschnede': set(['Abschnede']),
#  u'Achter de M\xf6hl': set([u'Achter de M\xf6hl']),
#  'Achtern Diek': set(['Achtern Diek']),
#  u'Achtern H\xf6ben': set([u'Achtern H\xf6ben']),
#  'Achtern Riep': set(['Achtern Riep']),
#  u'Achternstra\xdfe': set([u'Achternstra\xdfe']),
#  'Achters Kamp': set(['Achters Kamp']),
#  'Achterum': set(['Achterum']),
#  u'Ackerstra\xdfe': set([u'Ackerstra\xdfe']),
#  u'Adalbert-Stifter-Stra\xdfe': set([u'Adalbert-Stifter-Stra\xdfe']),
#  'Adenauerdamm': set(['Adenauerdamm']),
#  u'Adenauerstra\xdfe': set([u'Adenauerstra\xdfe']),
#  u'Adolfstra\xdfe': set([u'Adolfstra\xdfe']),
#  'Ahornweg': set(['Ahornweg']),
#  u'Airbus-Stra\xdfe': set([u'Airbus-Stra\xdfe']),
#  u'Albert-Hirsch-Stra\xdfe': set([u'Albert-Hirsch-Stra\xdfe']),
#  u'Albert-Pfitzer-Stra\xdfe': set([u'Albert-Pfitzer-Stra\xdfe']),
#  u'Albert-Schweitzer-Stra\xdfe': set([u'Albert-Schweitzer-Stra\xdfe']),
#  u'Allensteiner Stra\xdfe': set([u'Allensteiner Stra\xdfe']),
#  'Allmersallee': set(['Allmersallee']),
#  u'Alte Dorfstra\xdfe': set([u'Alte Dorfstra\xdfe']),
#  u'Alte M\xfchle': set([u'Alte M\xfchle']),
#  'Alte Schmiede': set(['Alte Schmiede']),
#  u'Alte Schulstra\xdfe': set([u'Alte Schulstra\xdfe']),
#  u'Alte Stra\xdfe': set([u'Alte Stra\xdfe']),
#  'Alte Trift': set(['Alte Trift']),
#  u'Altenbrucher Bahnhofstra\xdfe': set([u'Altenbrucher Bahnhofstra\xdfe']),
#  'Altenhafen': set(['Altenhafen']),
#  u'Altenm\xfchlen': set([u'Altenm\xfchlen']),
#  'Altenschleuse': set(['Altenschleuse']),
#  u'Altensieler Stra\xdfe': set([u'Altensieler Stra\xdfe']),
#  'Altenwalder Heideweg': set(['Altenwalder Heideweg']),
#  'Alter Deichweg': set(['Alter Deichweg']),
#  'Alter Kirchweg': set(['Alter Kirchweg']),
#  'Alter Postweg': set(['Alter Postweg']),
#  u'Altklosterbergstra\xdfe': set([u'Altklosterbergstra\xdfe']),
#  u'Altl\xe4nder Stra\xdfe': set([u'Altl\xe4nder Stra\xdfe']),
#  'Am Alten Deich': set(['Am Alten Deich']),
#  'Am Altendeich': set(['Am Altendeich']),
#  'Am Altenfeldsdeich': set(['Am Altenfeldsdeich']),
#  'Am Altenwalder Bahnhof': set(['Am Altenwalder Bahnhof']),
#  'Am Amtsgericht': set(['Am Amtsgericht']),
#  'Am Bahnhof': set(['Am Bahnhof']),
#  'Am Bassin': set(['Am Bassin']),
#  'Am Beek': set(['Am Beek']),
#  'Am Begrabenholz': set(['Am Begrabenholz']),
#  'Am Bentheim': set(['Am Bentheim']),
#  'Am Bolritt': set(['Am Bolritt']),
#  u'Am Bo\xdfelkamp': set([u'Am Bo\xdfelkamp']),
#  'Am Bullenhof': set(['Am Bullenhof']),
#  u'Am B\xfcrgerpark': set([u'Am B\xfcrgerpark']),
#  'Am Deich': set(['Am Deich']),
#  'Am Dorfrand': set(['Am Dorfrand']),
#  'Am Dorfteich': set(['Am Dorfteich']),
#  'Am Dornbusch': set(['Am Dornbusch']),
#  'Am Eichenweg': set(['Am Eichenweg']),
#  'Am Elbdeich': set(['Am Elbdeich']),
#  'Am Erlengrund': set(['Am Erlengrund']),
#  'Am Felde': set(['Am Felde']),
#  'Am Fischerklink': set(['Am Fischerklink']),
#  'Am Fischteich': set(['Am Fischteich']),
#  'Am Fleth': set(['Am Fleth']),
#  u'Am F\xe4hrhafen': set([u'Am F\xe4hrhafen']),
#  'Am Geestrand': set(['Am Geestrand']),
#  'Am Gemeindezentrum': set(['Am Gemeindezentrum']),
#  'Am Gerbergraben': set(['Am Gerbergraben']),
#  u'Am Gro\xdfen Specken': set([u'Am Gro\xdfen Specken']),
#  'Am Hafen': set(['Am Hafen']),
#  'Am Hang': set(['Am Hang']),
#  'Am Hechtgraben': set(['Am Hechtgraben']),
#  'Am Hohen Felde': set(['Am Hohen Felde']),
#  'Am Hohenwedel': set(['Am Hohenwedel']),
#  'Am Holzhafen': set(['Am Holzhafen']),
#  'Am Holzplatz': set(['Am Holzplatz']),
#  'Am Kamp': set(['Am Kamp']),
#  'Am Kanal': set(['Am Kanal']),
#  'Am Kriegerdenkmal': set(['Am Kriegerdenkmal']),
#  u'Am K\xf6nigshof': set([u'Am K\xf6nigshof']),
#  'Am Langenorth': set(['Am Langenorth']),
#  'Am Lohhof': set(['Am Lohhof']),
#  'Am Lunedeich': set(['Am Lunedeich']),
#  u'Am L\xe4ngengrad': set([u'Am L\xe4ngengrad']),
#  'Am Marktplatz': set(['Am Marktplatz']),
#  'Am Medemsand': set(['Am Medemsand']),
#  'Am Muschelplatz': set(['Am Muschelplatz']),
#  u'Am M\xfchlenhof': set([u'Am M\xfchlenhof']),
#  u'Am M\xfchlenteich': set([u'Am M\xfchlenteich']),
#  'Am Neuen Fleth': set(['Am Neuen Fleth']),
#  'Am Neuendeich': set(['Am Neuendeich']),
#  'Am Park': set(['Am Park']),
#  'Am Pfennigsberg': set(['Am Pfennigsberg']),
#  'Am Pferdehof': set(['Am Pferdehof']),
#  'Am Redder': set(['Am Redder']),
#  'Am Rhynschloot': set(['Am Rhynschloot']),
#  'Am Ries': set(['Am Ries']),
#  'Am Ringwall': set(['Am Ringwall']),
#  'Am Rosengarten': set(['Am Rosengarten']),
#  'Am Rosenhof': set(['Am Rosenhof']),
#  'Am Rugen End': set(['Am Rugen End']),
#  'Am Sahlenburger Strand': set(['Am Sahlenburger Strand']),
#  'Am Schafdamm': set(['Am Schafdamm']),
#  u'Am Schie\xdfstand': set([u'Am Schie\xdfstand']),
#  'Am Schwarzen Berg': set(['Am Schwarzen Berg']),
#  'Am Schwingedeich': set(['Am Schwingedeich']),
#  u'Am Sch\xe4ferstieg': set([u'Am Sch\xe4ferstieg']),
#  'Am Seepark': set(['Am Seepark']),
#  'Am Seniorenzentrum': set(['Am Seniorenzentrum']),
#  'Am Silbergras': set(['Am Silbergras']),
#  'Am Soesmenfeld': set(['Am Soesmenfeld']),
#  'Am Sportplatz': set(['Am Sportplatz']),
#  'Am Steinbeck': set(['Am Steinbeck']),
#  'Am Steinberg': set(['Am Steinberg']),
#  'Am Steinkamp': set(['Am Steinkamp']),
#  u'Am S\xfcdsee': set([u'Am S\xfcdsee']),
#  'Am Tannenkamp': set(['Am Tannenkamp']),
#  'Am Teich': set(['Am Teich']),
#  'Am Vorwerk': set(['Am Vorwerk']),
#  'Am Wald': set(['Am Wald']),
#  'Am Wegen': set(['Am Wegen']),
#  'Am Wendelberg': set(['Am Wendelberg']),
#  'Am Wichelboom': set(['Am Wichelboom']),
#  'Am Wischhof': set(['Am Wischhof']),
#  'Am Yachthafen': set(['Am Yachthafen']),
#  'Am Ziegelkamp': set(['Am Ziegelkamp']),
#  'Am alten Teich': set(['Am alten Teich']),
#  u'Amandastra\xdfe': set([u'Amandastra\xdfe']),
#  'Ampferweg': set(['Ampferweg']),
#  'Amselstieg': set(['Amselstieg']),
#  u'Amselstra\xdfe': set([u'Amselstra\xdfe']),
#  'Amselweg': set(['Amselweg']),
#  u'An de St\xf6p': set([u'An de St\xf6p']),
#  'An den Dorfwiesen': set(['An den Dorfwiesen']),
#  'An den Eichen': set(['An den Eichen']),
#  'An den Geestbergen': set(['An den Geestbergen']),
#  'An den Schwingewiesen': set(['An den Schwingewiesen']),
#  'An der Bahn': set(['An der Bahn']),
#  'An der Balge': set(['An der Balge']),
#  u'An der Bundesstra\xdfe': set([u'An der Bundesstra\xdfe']),
#  u'An der B\xf6rne': set([u'An der B\xf6rne']),
#  'An der Chaussee': set(['An der Chaussee']),
#  'An der Graft': set(['An der Graft']),
#  'An der Hellme': set(['An der Hellme']),
#  'An der Kirche': set(['An der Kirche']),
#  'An der Lehmkuhle': set(['An der Lehmkuhle']),
#  'An der Mondraute': set(['An der Mondraute']),
#  u'An der M\xfchle': set([u'An der M\xfchle']),
#  'An der Post': set(['An der Post']),
#  'An der Rehwiese': set(['An der Rehwiese']),
#  'An der Rennbahn': set(['An der Rennbahn']),
#  u'An der Sch\xe4ferei': set([u'An der Sch\xe4ferei']),
#  'An der Trift': set(['An der Trift']),
#  'An der Wettern': set(['An der Wettern']),
#  u'Andersenstra\xdfe': set([u'Andersenstra\xdfe']),
#  u'Ankeloher Stra\xdfe': set([u'Ankeloher Stra\xdfe']),
#  u'Anna-Tiessen-Stra\xdfe': set([u'Anna-Tiessen-Stra\xdfe']),
#  'Anna-Wiemer-Weg': set(['Anna-Wiemer-Weg']),
#  u'Annastra\xdfe': set([u'Annastra\xdfe']),
#  u'Anne-Frank-Stra\xdfe': set([u'Anne-Frank-Stra\xdfe']),
#  'Anne-Frank-Weg': set(['Anne-Frank-Weg']),
#  u'Annenstra\xdfe': set([u'Annenstra\xdfe']),
#  u'Annette-von-Droste-H\xfclshoff-Stra\xdfe': set([u'Annette-von-Droste-H\xfclshoff-Stra\xdfe']),
#  u'Ansgarstra\xdfe': set([u'Ansgarstra\xdfe']),
#  u'Anton-Biehl-Stra\xdfe': set([u'Anton-Biehl-Stra\xdfe']),
#  u'Anton-Flettner-Stra\xdfe': set([u'Anton-Flettner-Stra\xdfe']),
#  u'Anton-Schumacher-Stra\xdfe': set([u'Anton-Schumacher-Stra\xdfe']),
#  'Apelerweg': set(['Apelerweg']),
#  u'Apenrader Stra\xdfe': set([u'Apenrader Stra\xdfe']),
#  u'Archivstra\xdfe': set([u'Archivstra\xdfe']),
#  'Arentsee': set(['Arentsee']),
#  'Atenser Allee': set(['Atenser Allee']),
#  'Auenland': set(['Auenland']),
#  u'Auf dem Bl\xf6ken': set([u'Auf dem Bl\xf6ken']),
#  'Auf dem Brink': set(['Auf dem Brink']),
#  'Auf dem Deiche': set(['Auf dem Deiche']),
#  'Auf dem Hohen Rade': set(['Auf dem Hohen Rade']),
#  'Auf dem Schoner': set(['Auf dem Schoner']),
#  u'Auf den Schmal\xe4ckern': set([u'Auf den Schmal\xe4ckern']),
#  'Auf den Strengen': set(['Auf den Strengen']),
#  'Auf der Bark': set(['Auf der Bark']),
#  'Auf der Brack': set(['Auf der Brack']),
#  'Auf der Fregatte': set(['Auf der Fregatte']),
#  u'Auf der Hungerh\xf6rn': set([u'Auf der Hungerh\xf6rn']),
#  'Auf der Koppel': set(['Auf der Koppel']),
#  'Auf der Stroth': set(['Auf der Stroth']),
#  'Auf der Trift': set(['Auf der Trift']),
#  'Auf der Zwingburg': set(['Auf der Zwingburg']),
#  u'Austra\xdfe': set([u'Austra\xdfe']),
#  u'Bachstra\xdfe': set([u'Bachstra\xdfe']),
#  u'Bahnhofstra\xdfe': set([u'Bahnhofstra\xdfe']),
#  u'Bahnstra\xdfe': set([u'Bahnstra\xdfe']),
#  'Barger Weg': set(['Barger Weg']),
#  u'Barkhausenstra\xdfe': set([u'Barkhausenstra\xdfe']),
#  'Barlachring': set(['Barlachring']),
#  u'Barmstedter Stra\xdfe': set([u'Barmstedter Stra\xdfe']),
#  u'Bartelstra\xdfe': set([u'Bartelstra\xdfe']),
#  'Barthelskamp': set(['Barthelskamp']),
#  u'Basbecker Stra\xdfe': set([u'Basbecker Stra\xdfe']),
#  'Bassenfleth': set(['Bassenfleth']),
#  'Bauernkamp': set(['Bauernkamp']),
#  'Bauernpriel': set(['Bauernpriel']),
#  'Bauerweg': set(['Bauerweg']),
#  u'Baumhausstra\xdfe': set([u'Baumhausstra\xdfe']),
#  u'Beerster M\xfchlenweg': set([u'Beerster M\xfchlenweg']),
#  u'Beethovenstra\xdfe': set([u'Beethovenstra\xdfe']),
#  'Bei St. Wilhadi': set(['Bei St. Wilhadi']),
#  'Bei der Alten Post': set(['Bei der Alten Post']),
#  'Bei der Fischtreppe': set(['Bei der Fischtreppe']),
#  'Bei der Kirche': set(['Bei der Kirche']),
#  u'Bei der M\xfchle': set([u'Bei der M\xfchle']),
#  'Beim Kloster Dohren': set(['Beim Kloster Dohren']),
#  'Beim Schiffertor': set(['Beim Schiffertor']),
#  'Beim Schlagbaum': set(['Beim Schlagbaum']),
#  'Beim Soll': set(['Beim Soll']),
#  'Bekenreihe': set(['Bekenreihe']),
#  'Berg': set(['Berg']),
#  'Bergkoppel': set(['Bergkoppel']),
#  u'Bergstra\xdfe': set([u'Bergstra\xdfe']),
#  u'Berliner Stra\xdfe': set([u'Berliner Stra\xdfe']),
#  u'Bernhardstra\xdfe': set([u'Bernhardstra\xdfe']),
#  'Bertha-von-Suttner-Allee': set(['Bertha-von-Suttner-Allee']),
#  'Bertha-von-Suttner-Ring': set(['Bertha-von-Suttner-Ring']),
#  u'Besenbeker Stra\xdfe': set([u'Besenbeker Stra\xdfe']),
#  'Bestmannsweg': set(['Bestmannsweg']),
#  u'Bettina-von-Arnim-Stra\xdfe': set([u'Bettina-von-Arnim-Stra\xdfe']),
#  'Beufleth': set(['Beufleth']),
#  u'Beverstedter M\xfchlenstra\xdfe': set([u'Beverstedter M\xfchlenstra\xdfe']),
#  u'Bi de Sch\xfcnkoppel': set([u'Bi de Sch\xfcnkoppel']),
#  'Bielenberg': set(['Bielenberg']),
#  'Birkengrund': set(['Birkengrund']),
#  'Birkenweg': set(['Birkenweg']),
#  'Bischof-Albert-Weg': set(['Bischof-Albert-Weg']),
#  'Bischofshof': set(['Bischofshof']),
#  'Blumenring': set(['Blumenring']),
#  u'Blumenstra\xdfe': set([u'Blumenstra\xdfe']),
#  u'Bl\xfccherstra\xdfe': set([u'Bl\xfccherstra\xdfe']),
#  'Bockelpromenade': set(['Bockelpromenade']),
#  u'Bockhooper Stra\xdfe': set([u'Bockhooper Stra\xdfe']),
#  'Bockwischer Weg': set(['Bockwischer Weg']),
#  u'Boelckestra\xdfe': set([u'Boelckestra\xdfe']),
#  u'Bohlenstra\xdfe': set([u'Bohlenstra\xdfe']),
#  u'Bojestra\xdfe': set([u'Bojestra\xdfe']),
#  u'Bokelsesser Stra\xdfe': set([u'Bokelsesser Stra\xdfe']),
#  u'Boleh\xf6rn': set([u'Boleh\xf6rn']),
#  'Bollweg': set(['Bollweg']),
#  'Bookhorstweg': set(['Bookhorstweg']),
#  u'Bornh\xf6ftstra\xdfe': set([u'Bornh\xf6ftstra\xdfe']),
#  'Bornkamp': set(['Bornkamp']),
#  u'Botterh\xf6rn': set([u'Botterh\xf6rn']),
#  'Brachvogelweg': set(['Brachvogelweg']),
#  u'Brackmannstra\xdfe': set([u'Brackmannstra\xdfe']),
#  u'Brahmsstra\xdfe': set([u'Brahmsstra\xdfe']),
#  'Brameler Weg': set(['Brameler Weg']),
#  u'Brandenburger Stra\xdfe': set([u'Brandenburger Stra\xdfe']),
#  'Brandenburger Weg': set(['Brandenburger Weg']),
#  'Brandmoorweg': set(['Brandmoorweg']),
#  u'Brauerstra\xdfe': set([u'Brauerstra\xdfe']),
#  'Brauerweg': set(['Brauerweg']),
#  'Bredenbeeksweg': set(['Bredenbeeksweg']),
#  u'Breite Stra\xdfe': set([u'Breite Stra\xdfe']),
#  u'Breitenburger Stra\xdfe': set([u'Breitenburger Stra\xdfe']),
#  'Breiter Weg': set(['Breiter Weg']),
#  u'Bremer Stra\xdfe': set([u'Bremer Stra\xdfe']),
#  u'Bremerhavener Stra\xdfe': set([u'Bremerhavener Stra\xdfe']),
#  'Bremers Garten': set(['Bremers Garten']),
#  u'Bremerv\xf6rder Stra\xdfe': set([u'Bremerv\xf6rder Stra\xdfe']),
#  u'Breslauer Stra\xdfe': set([u'Breslauer Stra\xdfe']),
#  'Breslauer Weg': set(['Breslauer Weg']),
#  u'Briggstra\xdfe': set([u'Briggstra\xdfe']),
#  'Brokreihe': set(['Brokreihe']),
#  'Brombeerweg': set(['Brombeerweg']),
#  'Bronzeschmiede': set(['Bronzeschmiede']),
#  'Bruchteilsweg': set(['Bruchteilsweg']),
#  'Brunnenkamp': set(['Brunnenkamp']),
#  'Brunsburg': set(['Brunsburg']),
#  u'Brunsb\xfctteler Stra\xdfe': set([u'Brunsb\xfctteler Stra\xdfe']),
#  'Brunsholt': set(['Brunsholt']),
#  u'Buchenstra\xdfe': set([u'Buchenstra\xdfe']),
#  'Buchenweg': set(['Buchenweg']),
#  'Bucht': set(['Bucht']),
#  u'Buchtstra\xdfe': set([u'Buchtstra\xdfe']),
#  'Bullendorf': set(['Bullendorf']),
#  u'Bundesstra\xdfe': set([u'Bundesstra\xdfe']),
#  u'Burdiekstra\xdfe': set([u'Burdiekstra\xdfe']),
#  u'Burgstra\xdfe': set([u'Burgstra\xdfe']),
#  'Burgweide': set(['Burgweide']),
#  'Buschweg': set(['Buschweg']),
#  'Bussardweg': set(['Bussardweg']),
#  u'Buxtehuder Stra\xdfe': set([u'Buxtehuder Stra\xdfe']),
#  u'B\xf6berstroot': set([u'B\xf6berstroot']),
#  u'B\xf6ttcherring': set([u'B\xf6ttcherring']),
#  u'B\xfchler Weg': set([u'B\xfchler Weg']),
#  u'B\xfcndtwiete': set([u'B\xfcndtwiete']),
#  u'B\xfcntfeld': set([u'B\xfcntfeld']),
#  u'B\xfcrgerei': set([u'B\xfcrgerei']),
#  u'B\xfcrgermeister-Diercks-Stra\xdfe': set([u'B\xfcrgermeister-Diercks-Stra\xdfe']),
#  u'B\xfcrgermeister-Hogrefe-Stra\xdfe': set([u'B\xfcrgermeister-Hogrefe-Stra\xdfe']),
#  u'B\xfcrgermeister-Martin-Donandt-Platz': set([u'B\xfcrgermeister-Martin-Donandt-Platz']),
#  u'B\xfcrgermeister-Schinkel-Stra\xdfe': set([u'B\xfcrgermeister-Schinkel-Stra\xdfe']),
#  u'B\xfcrgermeister-Smidt-Stra\xdfe': set([u'B\xfcrgermeister-Smidt-Stra\xdfe']),
#  u'B\xfcrgermeister-Tesch-Stra\xdfe': set([u'B\xfcrgermeister-Tesch-Stra\xdfe']),
#  u'B\xfcttel': set([u'B\xfcttel']),
#  u'B\xfctteler Stra\xdfe': set([u'B\xfctteler Stra\xdfe']),
#  'Cappeler Altendeich': set(['Cappeler Altendeich']),
#  u'Carl-Hermann-Richter-Stra\xdfe': set([u'Carl-Hermann-Richter-Stra\xdfe']),
#  'Carl-Vinnen-Weg': set(['Carl-Vinnen-Weg']),
#  u'Carl-Zeiss-Stra\xdfe': set([u'Carl-Zeiss-Stra\xdfe']),
#  'Carlo-Schmid-Weg': set(['Carlo-Schmid-Weg']),
#  u'Catharinenstra\xdfe': set([u'Catharinenstra\xdfe']),
#  u'Chemnitzstra\xdfe': set([u'Chemnitzstra\xdfe']),
#  'Christa-Wehling-Weg': set(['Christa-Wehling-Weg']),
#  u'Christian-IV-Stra\xdfe': set([u'Christian-IV-Stra\xdfe']),
#  'Claus-Dammann-Weg': set(['Claus-Dammann-Weg']),
#  u'Claus-Gieschen-Stra\xdfe': set([u'Claus-Gieschen-Stra\xdfe']),
#  'Claustal': set(['Claustal']),
#  u'Cronemeyerstra\xdfe': set([u'Cronemeyerstra\xdfe']),
#  u'Cuxhavener Stra\xdfe': set([u'Cuxhavener Stra\xdfe']),
#  'Dachsbau': set(['Dachsbau']),
#  'Dahlienweg': set(['Dahlienweg']),
#  u'Daimlerstra\xdfe': set([u'Daimlerstra\xdfe']),
#  'Damm': set(['Damm']),
#  'Dammducht': set(['Dammducht']),
#  u'Dammhauser Stra\xdfe': set([u'Dammhauser Stra\xdfe']),
#  u'Dankersstra\xdfe': set([u'Dankersstra\xdfe']),
#  'Danziger Ring': set(['Danziger Ring']),
#  u'Danziger Stra\xdfe': set([u'Danziger Stra\xdfe']),
#  u'Debstedter Stra\xdfe': set([u'Debstedter Stra\xdfe']),
#  'Deichgrafenweg': set(['Deichgrafenweg']),
#  'Deichreihe': set(['Deichreihe']),
#  u'Deichstra\xdfe': set([u'Deichstra\xdfe']),
#  'Deichweg': set(['Deichweg']),
#  'Delmer Bogen': set(['Delmer Bogen']),
#  'Denkmalplatz': set(['Denkmalplatz']),
#  u'Dethlefsenstra\xdfe': set([u'Dethlefsenstra\xdfe']),
#  'Diedrich-Speckmann-Weg': set(['Diedrich-Speckmann-Weg']),
#  'Diekenhoper Ring': set(['Diekenhoper Ring']),
#  "Diers'sche Weide": set(["Diers'sche Weide"]),
#  'Diertgahren': set(['Diertgahren']),
#  'Dinkelweg': set(['Dinkelweg']),
#  'Disselfinkstroot': set(['Disselfinkstroot']),
#  u'Dithmarschenstra\xdfe': set([u'Dithmarschenstra\xdfe']),
#  'Doppelreihe': set(['Doppelreihe']),
#  'Dorfreihe': set(['Dorfreihe']),
#  u'Dorfstra\xdfe': set([u'Dorfstra\xdfe']),
#  u'Dorfstra\xdfe-Ost': set([u'Dorfstra\xdfe-Ost']),
#  u'Dorotheastra\xdfe': set([u'Dorotheastra\xdfe']),
#  'Dorumer Weg': set(['Dorumer Weg']),
#  u'Dovenm\xfchlen': set([u'Dovenm\xfchlen']),
#  'Drechslereck': set(['Drechslereck']),
#  u'Dresdener Stra\xdfe': set([u'Dresdener Stra\xdfe']),
#  'Drift': set(['Drift']),
#  'Drosselstieg': set(['Drosselstieg']),
#  'Drosselweg': set(['Drosselweg']),
#  'Dubbenweg': set(['Dubbenweg']),
#  u'Dunantstra\xdfe': set([u'Dunantstra\xdfe']),
#  u'D\xfcnenf\xe4hrstra\xdfe': set([u'D\xfcnenf\xe4hrstra\xdfe']),
#  u'D\xfcnnenreihe': set([u'D\xfcnnenreihe']),
#  u'D\xfcringer Stra\xdfe': set([u'D\xfcringer Stra\xdfe']),
#  'Eckdahl': set(['Eckdahl']),
#  u'Eckernfeldstra\xdfe': set([u'Eckernfeldstra\xdfe']),
#  u'Eddelaker Stra\xdfe': set([u'Eddelaker Stra\xdfe']),
#  u'Eduardstra\xdfe': set([u'Eduardstra\xdfe']),
#  u'Egenb\xfcttelweg': set([u'Egenb\xfcttelweg']),
#  'Eibenweg': set(['Eibenweg']),
#  u'Eichendorffstra\xdfe': set([u'Eichendorffstra\xdfe']),
#  'Eichengrund': set(['Eichengrund']),
#  'Eichenkamp': set(['Eichenkamp']),
#  u'Eichenstra\xdfe': set([u'Eichenstra\xdfe']),
#  'Eichenweg': set(['Eichenweg']),
#  'Eichholz': set(['Eichholz']),
#  u'Eidewardener Stra\xdfe': set([u'Eidewardener Stra\xdfe']),
#  u'Elbinger Stra\xdfe': set([u'Elbinger Stra\xdfe']),
#  u'Elbstra\xdfe': set([u'Elbstra\xdfe']),
#  u'Elisabeth-Selbert-Stra\xdfe': set([u'Elisabeth-Selbert-Stra\xdfe']),
#  'Ellerndamm': set(['Ellerndamm']),
#  u'Elmshorner Stra\xdfe': set([u'Elmshorner Stra\xdfe']),
#  'Elredefleth': set(['Elredefleth']),
#  u'Else-Klindtworth-Stra\xdfe': set([u'Else-Klindtworth-Stra\xdfe']),
#  'Elsterweg': set(['Elsterweg']),
#  'Erhardweg': set(['Erhardweg']),
#  'Erich-Ollenhauer-Weg': set(['Erich-Ollenhauer-Weg']),
#  'Erich-Schulz-Weg': set(['Erich-Schulz-Weg']),
#  'Erlengrund': set(['Erlengrund']),
#  'Erlenweg': set(['Erlenweg']),
#  u'Erna-Kayser-Stra\xdfe': set([u'Erna-Kayser-Stra\xdfe']),
#  u'Ernst-Barlach-Stra\xdfe': set([u'Ernst-Barlach-Stra\xdfe']),
#  u'Ernst-Behrens-Stra\xdfe': set([u'Ernst-Behrens-Stra\xdfe']),
#  'Ernst-Behrens-Weg': set(['Ernst-Behrens-Weg']),
#  u'Ernst-Bode-Stra\xdfe': set([u'Ernst-Bode-Stra\xdfe']),
#  'Ernst-Gehben-Weg': set(['Ernst-Gehben-Weg']),
#  'Ernst-Gock-Weg': set(['Ernst-Gock-Weg']),
#  u'Ernst-Tantzen-Stra\xdfe': set([u'Ernst-Tantzen-Stra\xdfe']),
#  'Eschenweg': set(['Eschenweg']),
#  u'Estetalstra\xdfe': set([u'Estetalstra\xdfe']),
#  'Estewiesen': set(['Estewiesen']),
#  u'Eupener Stra\xdfe': set([u'Eupener Stra\xdfe']),
#  u'Falkenstra\xdfe': set([u'Falkenstra\xdfe']),
#  'Falkenweg': set(['Falkenweg']),
#  'Farmers Ring': set(['Farmers Ring']),
#  u'Fasanenstra\xdfe': set([u'Fasanenstra\xdfe']),
#  'Fasanenweg': set(['Fasanenweg']),
#  'Fehrmoorweg': set(['Fehrmoorweg']),
#  'Feldhofplatz': set(['Feldhofplatz']),
#  u'Feldhofstra\xdfe': set([u'Feldhofstra\xdfe']),
#  'Feldrain': set(['Feldrain']),
#  u'Feldstra\xdfe': set([u'Feldstra\xdfe']),
#  u'Feuerst\xe4ttenweg': set([u'Feuerst\xe4ttenweg']),
#  'Fichtenweg': set(['Fichtenweg']),
#  'Fiefhusen': set(['Fiefhusen']),
#  u'Findorffstra\xdfe': set([u'Findorffstra\xdfe']),
#  'Finkenstieg': set(['Finkenstieg']),
#  'Finkenweg': set(['Finkenweg']),
#  'Fischerhof': set(['Fischerhof']),
#  'Fischersiedlung': set(['Fischersiedlung']),
#  'Fischkai': set(['Fischkai']),
#  'Flamweg': set(['Flamweg']),
#  u'Fleester Stra\xdfe': set([u'Fleester Stra\xdfe']),
#  u'Fleetstra\xdfe': set([u'Fleetstra\xdfe']),
#  'Fleien': set(['Fleien']),
#  u'Flensburger Stra\xdfe': set([u'Flensburger Stra\xdfe']),
#  'Fliederweg': set(['Fliederweg']),
#  u'Floriastra\xdfe': set([u'Floriastra\xdfe']),
#  u'Fl\xf6gelinger Stra\xdfe': set([u'Fl\xf6gelinger Stra\xdfe']),
#  'Forellenring': set(['Forellenring']),
#  u'Frankensteiner Stra\xdfe': set([u'Frankensteiner Stra\xdfe']),
#  u'Freiburger Stra\xdfe': set([u'Freiburger Stra\xdfe']),
#  u'Frelsdorfer Stra\xdfe': set([u'Frelsdorfer Stra\xdfe']),
#  u'Freudentheilstra\xdfe': set([u'Freudentheilstra\xdfe']),
#  'Friedhofsweg': set(['Friedhofsweg']),
#  u'Friedrich-Carl-Stra\xdfe': set([u'Friedrich-Carl-Stra\xdfe']),
#  u'Friedrich-Dedecke-Stra\xdfe': set([u'Friedrich-Dedecke-Stra\xdfe']),
#  u'Friedrich-Ebert-Stra\xdfe': set([u'Friedrich-Ebert-Stra\xdfe']),
#  u'Friedrich-Eggers-Stra\xdfe': set([u'Friedrich-Eggers-Stra\xdfe']),
#  u'Friedrich-Huth-Stra\xdfe': set([u'Friedrich-Huth-Stra\xdfe']),
#  'Friedrich-Plettke-Weg': set(['Friedrich-Plettke-Weg']),
#  'Friesenring': set(['Friesenring']),
#  'Frijagang': set(['Frijagang']),
#  'Fritz-Lau-Weg': set(['Fritz-Lau-Weg']),
#  u'Fritz-Reuter-Stra\xdfe': set([u'Fritz-Reuter-Stra\xdfe']),
#  'Fritz-Thiedemann-Weg': set(['Fritz-Thiedemann-Weg']),
#  u'Frommholdstra\xdfe': set([u'Frommholdstra\xdfe']),
#  'Fruchtallee': set(['Fruchtallee']),
#  u'Fr\xfchlingstra\xdfe': set([u'Fr\xfchlingstra\xdfe']),
#  'Fuchsgang': set(['Fuchsgang']),
#  'Fuchsweg': set(['Fuchsweg']),
#  'Fuhrenweg': set(['Fuhrenweg']),
#  'Fuhrmannsweg': set(['Fuhrmannsweg']),
#  u'F\xe4hrstra\xdfe': set([u'F\xe4hrstra\xdfe']),
#  u'F\xf6hrer Stra\xdfe': set([u'F\xf6hrer Stra\xdfe']),
#  u'F\xf6rn Sandweg': set([u'F\xf6rn Sandweg']),
#  u'F\xfclscherstra\xdfe': set([u'F\xfclscherstra\xdfe']),
#  'Galgenberg': set(['Galgenberg']),
#  'Gammenteil': set(['Gammenteil']),
#  u'Gartenstra\xdfe': set([u'Gartenstra\xdfe']),
#  'Gartenweg': set(['Gartenweg']),
#  u'Gau\xdfstra\xdfe': set([u'Gau\xdfstra\xdfe']),
#  u'Gebr\xfcder-Grimm-Weg': set([u'Gebr\xfcder-Grimm-Weg']),
#  'Geelbeksdamm': set(['Geelbeksdamm']),
#  u'Geestem\xfcnder Stra\xdfe': set([u'Geestem\xfcnder Stra\xdfe']),
#  u'Geestensether Stra\xdfe': set([u'Geestensether Stra\xdfe']),
#  u'Gerberstra\xdfe': set([u'Gerberstra\xdfe']),
#  u'Gerhard-Schr\xf6der-Stra\xdfe': set([u'Gerhard-Schr\xf6der-Stra\xdfe']),
#  'Gerlachweg': set(['Gerlachweg']),
#  'Gerlingweg': set(['Gerlingweg']),
#  'Gerstenkamp': set(['Gerstenkamp']),
#  'Giesenweg': set(['Giesenweg']),
#  u'Gildemeisterstra\xdfe': set([u'Gildemeisterstra\xdfe']),
#  'Ginsterweg': set(['Ginsterweg']),
#  'Glashofkamp': set(['Glashofkamp']),
#  u'Glatzer Stra\xdfe': set([u'Glatzer Stra\xdfe']),
#  'Glockenkamp': set(['Glockenkamp']),
#  u'Gl\xfcckauf II': set([u'Gl\xfcckauf II']),
#  u'Gl\xfcckst\xe4dter Stra\xdfe': set([u'Gl\xfcckst\xe4dter Stra\xdfe']),
#  u'Gnarrenburger Stra\xdfe': set([u'Gnarrenburger Stra\xdfe']),
#  'Godeke-Michels-Weg': set(['Godeke-Michels-Weg']),
#  'Godewindweg': set(['Godewindweg']),
#  u'Goebenstra\xdfe': set([u'Goebenstra\xdfe']),
#  u'Goethestra\xdfe': set([u'Goethestra\xdfe']),
#  u'Goldbekstra\xdfe': set([u'Goldbekstra\xdfe']),
#  u'Goosh\xf6ren': set([u'Goosh\xf6ren']),
#  u'Gorch-Fock-Stra\xdfe': set([u'Gorch-Fock-Stra\xdfe']),
#  'Gorch-Fock-Weg': set(['Gorch-Fock-Weg']),
#  u'Graf-Thietmar-Stra\xdfe': set([u'Graf-Thietmar-Stra\xdfe']),
#  u'Grashoffstra\xdfe': set([u'Grashoffstra\xdfe']),
#  'Grasweg': set(['Grasweg']),
#  'Grauer Wall': set(['Grauer Wall']),
#  'Grenzweg': set(['Grenzweg']),
#  'Greti-Grube-Weg': set(['Greti-Grube-Weg']),
#  'Grevenkoper Riep': set(['Grevenkoper Riep']),
#  'Grillchaussee': set(['Grillchaussee']),
#  u'Grothe-Marie-Stra\xdfe': set([u'Grothe-Marie-Stra\xdfe']),
#  u'Gro\xdf Kampen': set([u'Gro\xdf Kampen']),
#  u'Gro\xdfe Beek': set([u'Gro\xdfe Beek']),
#  u'Gro\xdfe Deichstra\xdfe': set([u'Gro\xdfe Deichstra\xdfe']),
#  u'Gro\xdfe Flage': set([u'Gro\xdfe Flage']),
#  u'Gro\xdfe Hardewiek': set([u'Gro\xdfe Hardewiek']),
#  u'Gro\xdfe Kirchreihe': set([u'Gro\xdfe Kirchreihe']),
#  u'Gro\xdfe Litt': set([u'Gro\xdfe Litt']),
#  u'Gro\xdfe N\xfcbelstra\xdfe': set([u'Gro\xdfe N\xfcbelstra\xdfe']),
#  u'Gro\xdfe Ortstra\xdfe': set([u'Gro\xdfe Ortstra\xdfe']),
#  u'Gro\xdfe Stra\xdfe': set([u'Gro\xdfe Stra\xdfe']),
#  u'Gro\xdfensieler Stra\xdfe': set([u'Gro\xdfensieler Stra\xdfe']),
#  u'Gro\xdfer Sand': set([u'Gro\xdfer Sand']),
#  u'Gro\xdfer Schwibbogen': set([u'Gro\xdfer Schwibbogen']),
#  u'Gro\xdfer Wulfhagen': set([u'Gro\xdfer Wulfhagen']),
#  u'Gr\xe4fenweg': set([u'Gr\xe4fenweg']),
#  u'Gr\xe4fin-Richardis-Stra\xdfe': set([u'Gr\xe4fin-Richardis-Stra\xdfe']),
#  u'Gr\xf6ngal': set([u'Gr\xf6ngal']),
#  u'Gr\xf6nland': set([u'Gr\xf6nland']),
#  u'Gr\xf6nlandstra\xdfe': set([u'Gr\xf6nlandstra\xdfe']),
#  u'Gr\xf6pelinger Stra\xdfe': set([u'Gr\xf6pelinger Stra\xdfe']),
#  u'Gr\xfcner Grund': set([u'Gr\xfcner Grund']),
#  u'Gr\xfcner Hof': set([u'Gr\xfcner Hof']),
#  u'Gr\xfcner Wald': set([u'Gr\xfcner Wald']),
#  'Guderhandviertel': set(['Guderhandviertel']),
#  u'Gustav-Augustin-Stra\xdfe': set([u'Gustav-Augustin-Stra\xdfe']),
#  u'Gustav-Heinemann-Stra\xdfe': set([u'Gustav-Heinemann-Stra\xdfe']),
#  'Gutenbergring': set(['Gutenbergring']),
#  u'Gu\xdfberg': set([u'Gu\xdfberg']),
#  u'G\xe4nsebl\xfcmchenweg': set([u'G\xe4nsebl\xfcmchenweg']),
#  u'G\xe4rtnerstra\xdfe': set([u'G\xe4rtnerstra\xdfe']),
#  'Habeckstal': set(['Habeckstal']),
#  u'Habichtstra\xdfe': set([u'Habichtstra\xdfe']),
#  u'Haderslebener Stra\xdfe': set([u'Haderslebener Stra\xdfe']),
#  u'Hafenstra\xdfe': set([u'Hafenstra\xdfe']),
#  'Haferkamp': set(['Haferkamp']),
#  'Hagedorn': set(['Hagedorn']),
#  'Hahler Weg': set(['Hahler Weg']),
#  'Hainholzer Damm': set(['Hainholzer Damm']),
#  u'Hake-Betcken-Stra\xdfe': set([u'Hake-Betcken-Stra\xdfe']),
#  'Halenbruk': set(['Halenbruk']),
#  u'Halepaghenstra\xdfe': set([u'Halepaghenstra\xdfe']),
#  u'Hallingstra\xdfe': set([u'Hallingstra\xdfe']),
#  u'Hamburger Stra\xdfe': set([u'Hamburger Stra\xdfe']),
#  'Hamsterweg': set(['Hamsterweg']),
#  'Hans Albers': set(['Hans Albers']),
#  u'Hans-B\xf6ckler-Stra\xdfe': set([u'Hans-B\xf6ckler-Stra\xdfe']),
#  u'Hansingstra\xdfe': set([u'Hansingstra\xdfe']),
#  u'Harburger Stra\xdfe': set([u'Harburger Stra\xdfe']),
#  u'Harsefelder Stra\xdfe': set([u'Harsefelder Stra\xdfe']),
#  u'Hartwigstra\xdfe': set([u'Hartwigstra\xdfe']),
#  'Hasenbusch': set(['Hasenbusch']),
#  'Hasenkamp': set(['Hasenkamp']),
#  u'Hastedtstra\xdfe': set([u'Hastedtstra\xdfe']),
#  'Hauffweg': set(['Hauffweg']),
#  u'Hauptmann-B\xf6se-Stra\xdfe': set([u'Hauptmann-B\xf6se-Stra\xdfe']),
#  u'Hauptstra\xdfe': set([u'Hauptstra\xdfe']),
#  u'Hebbelstra\xdfe': set([u'Hebbelstra\xdfe']),
#  'Heckenrosenweg': set(['Heckenrosenweg']),
#  u'Hedwig-Augustin-Stra\xdfe': set([u'Hedwig-Augustin-Stra\xdfe']),
#  u'Heerstedter Stra\xdfe': set([u'Heerstedter Stra\xdfe']),
#  u'Hegelstra\xdfe': set([u'Hegelstra\xdfe']),
#  'Heidbecker Weg': set(['Heidbecker Weg']),
#  'Heideweg': set(['Heideweg']),
#  'Heidgrabener Weg': set(['Heidgrabener Weg']),
#  'Heidkamp': set(['Heidkamp']),
#  u'Heidm\xfchlenweg': set([u'Heidm\xfchlenweg']),
#  'Heidort': set(['Heidort']),
#  u'Heimbrucher Stra\xdfe': set([u'Heimbrucher Stra\xdfe']),
#  u'Heinrich-B\xf6ll-Stra\xdfe': set([u'Heinrich-B\xf6ll-Stra\xdfe']),
#  u'Heinrich-Hauschildt-Stra\xdfe': set([u'Heinrich-Hauschildt-Stra\xdfe']),
#  u'Heinrich-Luden-Stra\xdfe': set([u'Heinrich-Luden-Stra\xdfe']),
#  u'Heinrich-Wagner-Stra\xdfe': set([u'Heinrich-Wagner-Stra\xdfe']),
#  'Heinrich-von-Brentano-Weg': set(['Heinrich-von-Brentano-Weg']),
#  u'Heinrichstra\xdfe': set([u'Heinrichstra\xdfe']),
#  'Heisterender Chaussee': set(['Heisterender Chaussee']),
#  'Heisterkamp': set(['Heisterkamp']),
#  'Heisterstroot': set(['Heisterstroot']),
#  'Heitmannshausen': set(['Heitmannshausen']),
#  'Helga-Wex-Platz': set(['Helga-Wex-Platz']),
#  'Helmsand': set(['Helmsand']),
#  u'Henneke-Wulf-Stra\xdfe': set([u'Henneke-Wulf-Stra\xdfe']),
#  'Hennmoor': set(['Hennmoor']),
#  'Henry-Dunant-Ring': set(['Henry-Dunant-Ring']),
#  u'Herbert-Huster-Stra\xdfe': set([u'Herbert-Huster-Stra\xdfe']),
#  u'Hermann-Allmers-Stra\xdfe': set([u'Hermann-Allmers-Stra\xdfe']),
#  'Hermann-Daur-Weg': set(['Hermann-Daur-Weg']),
#  'Hermann-Ehlers-Weg': set(['Hermann-Ehlers-Weg']),
#  u'Hermann-L\xf6ns-Stra\xdfe': set([u'Hermann-L\xf6ns-Stra\xdfe']),
#  'Hermann-Sudermann-Allee': set(['Hermann-Sudermann-Allee']),
#  u'Hermann-Weyl-Stra\xdfe': set([u'Hermann-Weyl-Stra\xdfe']),
#  'Hermelinweg': set(['Hermelinweg']),
#  u'Herrenstra\xdfe': set([u'Herrenstra\xdfe']),
#  'Herzhorner Rhin': set(['Herzhorner Rhin']),
#  u'Herzog-Erich-Stra\xdfe': set([u'Herzog-Erich-Stra\xdfe']),
#  'Heubruchsweg': set(['Heubruchsweg']),
#  u'Heuss-Stra\xdfe': set([u'Heuss-Stra\xdfe']),
#  u'Hindenburgstra\xdfe': set([u'Hindenburgstra\xdfe']),
#  'Hinter dem Dorf': set(['Hinter dem Dorf']),
#  'Hinter dem Heidedeich': set(['Hinter dem Heidedeich']),
#  'Hinter dem Zwinger': set(['Hinter dem Zwinger']),
#  'Hinter den Eichen': set(['Hinter den Eichen']),
#  u'Hinter den H\xf6fen': set([u'Hinter den H\xf6fen']),
#  'Hinter der Linah': set(['Hinter der Linah']),
#  'Hinterbrack': set(['Hinterbrack']),
#  'Hinterm Bruch': set(['Hinterm Bruch']),
#  'Hinterm Dorf': set(['Hinterm Dorf']),
#  'Hinterm Hof': set(['Hinterm Hof']),
#  'Hinterm Holz': set(['Hinterm Holz']),
#  u'Hinterstra\xdfe': set([u'Hinterstra\xdfe']),
#  u'Hirschberger Stra\xdfe': set([u'Hirschberger Stra\xdfe']),
#  'Hochfeld': set(['Hochfeld']),
#  u'Hohenfriedberger Stra\xdfe': set([u'Hohenfriedberger Stra\xdfe']),
#  u'Hohenstaufenstra\xdfe': set([u'Hohenstaufenstra\xdfe']),
#  'Hoher Kamp': set(['Hoher Kamp']),
#  'Hohes Feld': set(['Hohes Feld']),
#  'Hohewurth': set(['Hohewurth']),
#  u'Hohewurthstra\xdfe': set([u'Hohewurthstra\xdfe']),
#  u'Holbeinstra\xdfe': set([u'Holbeinstra\xdfe']),
#  u'Hollernstra\xdfe': set([u'Hollernstra\xdfe']),
#  'Hollerwettern': set(['Hollerwettern']),
#  'Holstendorf': set(['Holstendorf']),
#  'Holtenborn': set(['Holtenborn']),
#  u'Holunderstra\xdfe': set([u'Holunderstra\xdfe']),
#  'Holunderweg': set(['Holunderweg']),
#  u'Holzstra\xdfe': set([u'Holzstra\xdfe']),
#  u'Horneburger Stra\xdfe': set([u'Horneburger Stra\xdfe']),
#  'Hornskuhle': set(['Hornskuhle']),
#  u'Horster Landstra\xdfe': set([u'Horster Landstra\xdfe']),
#  'Horstheider Weg': set(['Horstheider Weg']),
#  u'Horststra\xdfe': set([u'Horststra\xdfe']),
#  u'Hoserm\xfchlener Stra\xdfe': set([u'Hoserm\xfchlener Stra\xdfe']),
#  'Huddelberg': set(['Huddelberg']),
#  u'Hugo-Wolf-Stra\xdfe': set([u'Hugo-Wolf-Stra\xdfe']),
#  'Hummelweg': set(['Hummelweg']),
#  'Hymendorfer Chaussee': set(['Hymendorfer Chaussee']),
#  u'H\xf6chststadt': set([u'H\xf6chststadt']),
#  u'H\xf6gertwiete': set([u'H\xf6gertwiete']),
#  u'H\xf6kerstra\xdfe': set([u'H\xf6kerstra\xdfe']),
#  u'H\xf6rn': set([u'H\xf6rn']),
#  u'H\xf6rnstra\xdfe': set([u'H\xf6rnstra\xdfe']),
#  u'H\xfcgelweg': set([u'H\xfcgelweg']),
#  'I. Moorwiese': set(['I. Moorwiese']),
#  'III. Sandereiweg': set(['III. Sandereiweg']),
#  u'Ilsestra\xdfe': set([u'Ilsestra\xdfe']),
#  'Iltisweg': set(['Iltisweg']),
#  'Im Brande': set(['Im Brande']),
#  u'Im B\xfcttelfeld': set([u'Im B\xfcttelfeld']),
#  'Im Dallfordel': set(['Im Dallfordel']),
#  'Im Dicken Hop': set(['Im Dicken Hop']),
#  'Im Felde': set(['Im Felde']),
#  u'Im Gr\xfcnen Tale': set([u'Im Gr\xfcnen Tale']),
#  'Im Haselbusch': set(['Im Haselbusch']),
#  'Im Hufeisen': set(['Im Hufeisen']),
#  u'Im H\xfclsenbusch': set([u'Im H\xfclsenbusch']),
#  'Im Keil': set(['Im Keil']),
#  'Im Kleinen Sande': set(['Im Kleinen Sande']),
#  'Im Kloster': set(['Im Kloster']),
#  'Im Kornfeld': set(['Im Kornfeld']),
#  u'Im K\xf6llner Feld': set([u'Im K\xf6llner Feld']),
#  'Im Langen Feld': set(['Im Langen Feld']),
#  u'Im L\xfcbschen Recht': set([u'Im L\xfcbschen Recht']),
#  'Im Mittelteil': set(['Im Mittelteil']),
#  u'Im M\xfchlenfeld': set([u'Im M\xfchlenfeld']),
#  'Im Nordfelde': set(['Im Nordfelde']),
#  'Im Obstgarten': set(['Im Obstgarten']),
#  'Im Petersmoor': set(['Im Petersmoor']),
#  'Im Ring': set(['Im Ring']),
#  'Im Sande': set(['Im Sande']),
#  'Im Sicken': set(['Im Sicken']),
#  'Im Sohrfeld': set(['Im Sohrfeld']),
#  'Im Stuck': set(['Im Stuck']),
#  'Im Tweyad': set(['Im Tweyad']),
#  'Im Wiebusch': set(['Im Wiebusch']),
#  'Im Winkel': set(['Im Winkel']),
#  u'Immelmannstra\xdfe': set([u'Immelmannstra\xdfe']),
#  'Immenbecker Moorweg': set(['Immenbecker Moorweg']),
#  'Immenhofweg': set(['Immenhofweg']),
#  'In de Huuk': set(['In de Huuk']),
#  u'In den Niederh\xf6fen': set([u'In den Niederh\xf6fen']),
#  'In den Wiesen': set(['In den Wiesen']),
#  'In der Heide': set(['In der Heide']),
#  'In der Hellen': set(['In der Hellen']),
#  'In der Ohe': set(['In der Ohe']),
#  u'Industriestra\xdfe': set([u'Industriestra\xdfe']),
#  'Ingeborg-Bachmann-Weg': set(['Ingeborg-Bachmann-Weg']),
#  u'Ingwer-Paulsen-Stra\xdfe': set([u'Ingwer-Paulsen-Stra\xdfe']),
#  'Inne Beek': set(['Inne Beek']),
#  u'Irena-Sendler-Stra\xdfe': set([u'Irena-Sendler-Stra\xdfe']),
#  'Jahnring': set(['Jahnring']),
#  u'Jahnstra\xdfe': set([u'Jahnstra\xdfe']),
#  'Jierweg': set(['Jierweg']),
#  u'Johann-Diedrich-M\xf6ller-Stra\xdfe': set([u'Johann-Diedrich-M\xf6ller-Stra\xdfe']),
#  u'Johann-Kleen-Stra\xdfe': set([u'Johann-Kleen-Stra\xdfe']),
#  'Johann-von-Schulte-Platz': set(['Johann-von-Schulte-Platz']),
#  u'Johannesstra\xdfe': set([u'Johannesstra\xdfe']),
#  u'Johannisstra\xdfe': set([u'Johannisstra\xdfe']),
#  u'Jorker Stra\xdfe': set([u'Jorker Stra\xdfe']),
#  'Junkernhof': set(['Junkernhof']),
#  'Junkernhose': set(['Junkernhose']),
#  u'Justus-von-Liebig-Stra\xdfe': set([u'Justus-von-Liebig-Stra\xdfe']),
#  u'J\xe4gerstra\xdfe': set([u'J\xe4gerstra\xdfe']),
#  u'J\xfcrgen-Brand-Stra\xdfe': set([u'J\xfcrgen-Brand-Stra\xdfe']),
#  u'J\xfctlandstra\xdfe': set([u'J\xfctlandstra\xdfe']),
#  'KIefhorst': set(['KIefhorst']),
#  'Kalkwiesen': set(['Kalkwiesen']),
#  'Kaltenweide': set(['Kaltenweide']),
#  'Kamerland': set(['Kamerland']),
#  'Kampen': set(['Kampen']),
#  u'Kanalstra\xdfe': set([u'Kanalstra\xdfe']),
#  u'Kantstra\xdfe': set([u'Kantstra\xdfe']),
#  'Karl-Carstens-Ring': set(['Karl-Carstens-Ring']),
#  'Karl-Ernst-Levy-Weg': set(['Karl-Ernst-Levy-Weg']),
#  u'Karl-Friederich-Stra\xdfe': set([u'Karl-Friederich-Stra\xdfe']),
#  u'Karl-K\xfchlcke-Stra\xdfe': set([u'Karl-K\xfchlcke-Stra\xdfe']),
#  u'Karlstra\xdfe': set([u'Karlstra\xdfe']),
#  u'Karmeliterstra\xdfe': set([u'Karmeliterstra\xdfe']),
#  'Kastanienweg': set(['Kastanienweg']),
#  'Katenkoppel': set(['Katenkoppel']),
#  'Kattenkopp': set(['Kattenkopp']),
#  u'Kautzstra\xdfe': set([u'Kautzstra\xdfe']),
#  u'Kehdinger Stra\xdfe': set([u'Kehdinger Stra\xdfe']),
#  u'Keilstra\xdfe': set([u'Keilstra\xdfe']),
#  u'Kelterbornstra\xdfe': set([u'Kelterbornstra\xdfe']),
#  'Kiebitzmoor': set(['Kiebitzmoor']),
#  'Kiebitzreiher Chaussee': set(['Kiebitzreiher Chaussee']),
#  'Kiebitzstieg': set(['Kiebitzstieg']),
#  'Kiebitzweg': set(['Kiebitzweg']),
#  'Kiefernweg': set(['Kiefernweg']),
#  'Kiek Ut': set(['Kiek Ut']),
#  u'Kiel\xf6hr': set([u'Kiel\xf6hr']),
#  'Kirchdorf': set(['Kirchdorf']),
#  'Kirchducht': set(['Kirchducht']),
#  u'Kirchenstra\xdfe': set([u'Kirchenstra\xdfe']),
#  'Kirchenweg': set(['Kirchenweg']),
#  'Kirchweg': set(['Kirchweg']),
#  'Kirchwegallee': set(['Kirchwegallee']),
#  'Klarer Streck': set(['Klarer Streck']),
#  u'Klaus-Groth-Stra\xdfe': set([u'Klaus-Groth-Stra\xdfe']),
#  'Klaus-Groth-Weg': set(['Klaus-Groth-Weg']),
#  'Kleiner Ring': set(['Kleiner Ring']),
#  'Kleiner Rungenberg': set(['Kleiner Rungenberg']),
#  u'Kleiststra\xdfe': set([u'Kleiststra\xdfe']),
#  u'Klinth\xf6fe': set([u'Klinth\xf6fe']),
#  'Klosterdamm': set(['Klosterdamm']),
#  u'Klosterfeldstra\xdfe': set([u'Klosterfeldstra\xdfe']),
#  'Klosterhof': set(['Klosterhof']),
#  'Klostersande': set(['Klostersande']),
#  'Klotzenkuhle': set(['Klotzenkuhle']),
#  u'Kl\xfcverbaum': set([u'Kl\xfcverbaum']),
#  'Knechtsand': set(['Knechtsand']),
#  'Kniepsand': set(['Kniepsand']),
#  'Koggenweg': set(['Koggenweg']),
#  u'Kolberger Stra\xdfe': set([u'Kolberger Stra\xdfe']),
#  u'Kommodore-Johnsen-Stra\xdfe': set([u'Kommodore-Johnsen-Stra\xdfe']),
#  u'Konrad-Struve-Stra\xdfe': set([u'Konrad-Struve-Stra\xdfe']),
#  u'Koogstra\xdfe': set([u'Koogstra\xdfe']),
#  'Koppeldamm': set(['Koppeldamm']),
#  'Koppelring': set(['Koppelring']),
#  'Kormorangang': set(['Kormorangang']),
#  'Kormoranweg': set(['Kormoranweg']),
#  'Kornblumenweg': set(['Kornblumenweg']),
#  u'Korvettenstra\xdfe': set([u'Korvettenstra\xdfe']),
#  u'Kottmeierstra\xdfe': set([u'Kottmeierstra\xdfe']),
#  'Kremper Rhin': set(['Kremper Rhin']),
#  'Kreuzweg': set(['Kreuzweg']),
#  'Krittelmoor': set(['Krittelmoor']),
#  u'Krokusstra\xdfe': set([u'Krokusstra\xdfe']),
#  'Krokusweg': set(['Krokusweg']),
#  u'Krumme Stra\xdfe': set([u'Krumme Stra\xdfe']),
#  u'Kr\xfcselstra\xdfe': set([u'Kr\xfcselstra\xdfe']),
#  'Kuhlworth': set(['Kuhlworth']),
#  u'Kurze Stra\xdfe': set([u'Kurze Stra\xdfe']),
#  u'K\xe4ferstieg': set([u'K\xe4ferstieg']),
#  u'K\xe4rntner Stra\xdfe': set([u'K\xe4rntner Stra\xdfe']),
#  u'K\xe4the-Kollwitz-Platz': set([u'K\xe4the-Kollwitz-Platz']),
#  u'K\xe4the-Ringe-Stra\xdfe': set([u'K\xe4the-Ringe-Stra\xdfe']),
#  u'K\xe4thnerstra\xdfe': set([u'K\xe4thnerstra\xdfe']),
#  u'K\xf6llner Chaussee': set([u'K\xf6llner Chaussee']),
#  u'K\xf6nigreicher Stra\xdfe': set([u'K\xf6nigreicher Stra\xdfe']),
#  u'K\xf6nigsberger Stra\xdfe': set([u'K\xf6nigsberger Stra\xdfe']),
#  u'K\xf6nigsbergstra\xdfe': set([u'K\xf6nigsbergstra\xdfe']),
#  u'K\xf6nigsfelder Stra\xdfe': set([u'K\xf6nigsfelder Stra\xdfe']),
#  u'K\xf6nigstra\xdfe': set([u'K\xf6nigstra\xdfe']),
#  u'K\xf6nigsweg': set([u'K\xf6nigsweg']),
#  u'K\xf6rnerstra\xdfe': set([u'K\xf6rnerstra\xdfe']),
#  u'K\xf6sliner Stra\xdfe': set([u'K\xf6sliner Stra\xdfe']),
#  u'K\xf6thnerweg': set([u'K\xf6thnerweg']),
#  u'K\xfcsterkoppel': set([u'K\xfcsterkoppel']),
#  u'K\xfcstriner Stra\xdfe': set([u'K\xfcstriner Stra\xdfe']),
#  u'K\xfcvers Trift': set([u'K\xfcvers Trift']),
#  u'Landesbr\xfcck': set([u'Landesbr\xfcck']),
#  'Landweg': set(['Landweg']),
#  u'Landw\xfcrder Stra\xdfe': set([u'Landw\xfcrder Stra\xdfe']),
#  u'Lange Stra\xdfe': set([u'Lange Stra\xdfe']),
#  'Langelohe': set(['Langelohe']),
#  u'Langenbeckstra\xdfe': set([u'Langenbeckstra\xdfe']),
#  u'Langener Landstra\xdfe': set([u'Langener Landstra\xdfe']),
#  'Langenhals': set(['Langenhals']),
#  'Langenkamp': set(['Langenkamp']),
#  u'Langobardenstra\xdfe': set([u'Langobardenstra\xdfe']),
#  'Lauenberg': set(['Lauenberg']),
#  u'Lavener Stra\xdfe': set([u'Lavener Stra\xdfe']),
#  'Leerkenweg': set(['Leerkenweg']),
#  u'Leher Landstra\xdfe': set([u'Leher Landstra\xdfe']),
#  'Lehmweg': set(['Lehmweg']),
#  u'Lerchenh\xf6he': set([u'Lerchenh\xf6he']),
#  u'Lerchenstra\xdfe': set([u'Lerchenstra\xdfe']),
#  'Lerchenweg': set(['Lerchenweg']),
#  'Lesigfeld': set(['Lesigfeld']),
#  u'Lessingstra\xdfe': set([u'Lessingstra\xdfe']),
#  u'Liegnitzer Stra\xdfe': set([u'Liegnitzer Stra\xdfe']),
#  'Lieth': set(['Lieth']),
#  'Liether Moor': set(['Liether Moor']),
#  'Liether Ring': set(['Liether Ring']),
#  u'Lilienthalstra\xdfe': set([u'Lilienthalstra\xdfe']),
#  u'Lina-Meyer-Stra\xdfe': set([u'Lina-Meyer-Stra\xdfe']),
#  'Lindenallee': set(['Lindenallee']),
#  u'Lindenstra\xdfe': set([u'Lindenstra\xdfe']),
#  'Lindenweg': set(['Lindenweg']),
#  'Linnthun': set(['Linnthun']),
#  u'Lohmannstra\xdfe': set([u'Lohmannstra\xdfe']),
#  'Lorenzweg': set(['Lorenzweg']),
#  u'Lornsenstra\xdfe': set([u'Lornsenstra\xdfe']),
#  u'Lortzingstra\xdfe': set([u'Lortzingstra\xdfe']),
#  'Lotsenweg': set(['Lotsenweg']),
#  u'Louis-Mendel-Stra\xdfe': set([u'Louis-Mendel-Stra\xdfe']),
#  'Louise-Schroeder-Ring': set(['Louise-Schroeder-Ring']),
#  u'Ludwig-Meyn-Stra\xdfe': set([u'Ludwig-Meyn-Stra\xdfe']),
#  u'Ludwig-Thoma-Stra\xdfe': set([u'Ludwig-Thoma-Stra\xdfe']),
#  u'Ludwigstra\xdfe': set([u'Ludwigstra\xdfe']),
#  u'Luise-W\xf6lber-Weg': set([u'Luise-W\xf6lber-Weg']),
#  u'Luisenstra\xdfe': set([u'Luisenstra\xdfe']),
#  u'Lunestra\xdfe': set([u'Lunestra\xdfe']),
#  'Lurup': set(['Lurup']),
#  u'Lutherstra\xdfe': set([u'Lutherstra\xdfe']),
#  'Luttge-Marie-Weg': set(['Luttge-Marie-Weg']),
#  u'Lycker Stra\xdfe': set([u'Lycker Stra\xdfe']),
#  u'L\xe4rchenweg': set([u'L\xe4rchenweg']),
#  u'L\xf6nsweg': set([u'L\xf6nsweg']),
#  u'L\xf6wenzahnweg': set([u'L\xf6wenzahnweg']),
#  u'L\xfcbscher Kamp': set([u'L\xfcbscher Kamp']),
#  u'L\xfcbscher Landweg': set([u'L\xfcbscher Landweg']),
#  u'L\xfcdenstorfer Feld': set([u'L\xfcdenstorfer Feld']),
#  u'L\xfcderitzstra\xdfe': set([u'L\xfcderitzstra\xdfe']),
#  u'L\xfcdingworther Stra\xdfe': set([u'L\xfcdingworther Stra\xdfe']),
#  u'L\xfclanden': set([u'L\xfclanden']),
#  u'L\xfcneburger Schanze': set([u'L\xfcneburger Schanze']),
#  u'L\xfctt Moor': set([u'L\xfctt Moor']),
#  u'L\xfctzowstra\xdfe': set([u'L\xfctzowstra\xdfe']),
#  u'Magdalenenstra\xdfe': set([u'Magdalenenstra\xdfe']),
#  'Magdeburger Weg': set(['Magdeburger Weg']),
#  'Mainkamp': set(['Mainkamp']),
#  u'Marcusstra\xdfe': set([u'Marcusstra\xdfe']),
#  u'Margarete-Jansen-Stra\xdfe': set([u'Margarete-Jansen-Stra\xdfe']),
#  u'Marie-Elisabeth-L\xfcders-Stra\xdfe': set([u'Marie-Elisabeth-L\xfcders-Stra\xdfe']),
#  u'Marie-Juchacz-Stra\xdfe': set([u'Marie-Juchacz-Stra\xdfe']),
#  u'Marienburger Stra\xdfe': set([u'Marienburger Stra\xdfe']),
#  u'Marienstra\xdfe': set([u'Marienstra\xdfe']),
#  u'Marienwerderstra\xdfe': set([u'Marienwerderstra\xdfe']),
#  'Marinebahn': set(['Marinebahn']),
#  'Marktpassage': set(['Marktpassage']),
#  u'Marktstra\xdfe': set([u'Marktstra\xdfe']),
#  'Marschdamm': set(['Marschdamm']),
#  'Martin-Luther-Weg': set(['Martin-Luther-Weg']),
#  u'Mattenburger Stra\xdfe': set([u'Mattenburger Stra\xdfe']),
#  'Max-Beckmann-Platz': set(['Max-Beckmann-Platz']),
#  'Max-Kahlcke-Weg': set(['Max-Kahlcke-Weg']),
#  u'Max-Liebermann-Stra\xdfe': set([u'Max-Liebermann-Stra\xdfe']),
#  u'Max-Planck-Stra\xdfe': set([u'Max-Planck-Stra\xdfe']),
#  'Mecklenburger Weg': set(['Mecklenburger Weg']),
#  'Meisenweg': set(['Meisenweg']),
#  u'Meisterstra\xdfe': set([u'Meisterstra\xdfe']),
#  'Melau': set(['Melau']),
#  'Melkerweg': set(['Melkerweg']),
#  'Mellumplate': set(['Mellumplate']),
#  'Mellumring': set(['Mellumring']),
#  u'Memeler Stra\xdfe': set([u'Memeler Stra\xdfe']),
#  u'Me\xdftorffstra\xdfe': set([u'Me\xdftorffstra\xdfe']),
#  u'Midlumer Stra\xdfe': set([u'Midlumer Stra\xdfe']),
#  u'Mildred-Scheel-Stra\xdfe': set([u'Mildred-Scheel-Stra\xdfe']),
#  'Mittelfeld': set(['Mittelfeld']),
#  'Mittelskamp': set(['Mittelskamp']),
#  u'Mittelstenaher Stra\xdfe': set([u'Mittelstenaher Stra\xdfe']),
#  u'Mittelstra\xdfe': set([u'Mittelstra\xdfe']),
#  'Mittelweg': set(['Mittelweg']),
#  u'Molkenbuhrstra\xdfe': set([u'Molkenbuhrstra\xdfe']),
#  u'Moltkestra\xdfe': set([u'Moltkestra\xdfe']),
#  u'Mommsenstra\xdfe': set([u'Mommsenstra\xdfe']),
#  'Moorblick': set(['Moorblick']),
#  'Moordamm': set(['Moordamm']),
#  'Moordiek': set(['Moordiek']),
#  'Moorhusen': set(['Moorhusen']),
#  u'Moorstra\xdfe': set([u'Moorstra\xdfe']),
#  u'Moortorstra\xdfe': set([u'Moortorstra\xdfe']),
#  'Moortwiete': set(['Moortwiete']),
#  'Moorweg': set(['Moorweg']),
#  'Morgenland': set(['Morgenland']),
#  u'Morthorststra\xdfe': set([u'Morthorststra\xdfe']),
#  u'Mozartstra\xdfe': set([u'Mozartstra\xdfe']),
#  'Mozartweg': set(['Mozartweg']),
#  'Muchelndorf': set(['Muchelndorf']),
#  u'Muschelstra\xdfe': set([u'Muschelstra\xdfe']),
#  u'Mushardstra\xdfe': set([u'Mushardstra\xdfe']),
#  'Mushardweg': set(['Mushardweg']),
#  u'Myliusstra\xdfe': set([u'Myliusstra\xdfe']),
#  'Myrtenring': set(['Myrtenring']),
#  u'M\xf6hlendiek': set([u'M\xf6hlendiek']),
#  u'M\xf6hlenkamp': set([u'M\xf6hlenkamp']),
#  u'M\xfcggendorfer Stra\xdfe': set([u'M\xfcggendorfer Stra\xdfe']),
#  u'M\xfchlengrund': set([u'M\xfchlengrund']),
#  u'M\xfchlenkamp': set([u'M\xfchlenkamp']),
#  u'M\xfchlenkampsweg': set([u'M\xfchlenkampsweg']),
#  u'M\xfchlenstra\xdfe': set([u'M\xfchlenstra\xdfe']),
#  u'M\xfchlenweg': set([u'M\xfchlenweg']),
#  u'M\xfchlenweide': set([u'M\xfchlenweide']),
#  u'M\xfcritzweg': set([u'M\xfcritzweg']),
#  'Nachtigallentwiete': set(['Nachtigallentwiete']),
#  'Nachtigallenweg': set(['Nachtigallenweg']),
#  u'Neern in D\xf6rp': set([u'Neern in D\xf6rp']),
#  'Neidenburger Weg': set(['Neidenburger Weg']),
#  u'Nei\xdfestra\xdfe': set([u'Nei\xdfestra\xdfe']),
#  'Nelkenweg': set(['Nelkenweg']),
#  'Neu-Seeland': set(['Neu-Seeland']),
#  'Neue Reihe': set(['Neue Reihe']),
#  u'Neue Stra\xdfe': set([u'Neue Stra\xdfe']),
#  'Neuenschleuse': set(['Neuenschleuse']),
#  'Neuer Weg': set(['Neuer Weg']),
#  'Neufelder Weg': set(['Neufelder Weg']),
#  u'Neufundlandstra\xdfe': set([u'Neufundlandstra\xdfe']),
#  'Neukloster Str.': set(['Neukloster Str.']),
#  'Neuland': set(['Neuland']),
#  u'Neumarktstra\xdfe': set([u'Neumarktstra\xdfe']),
#  u'Neum\xfchlen': set([u'Neum\xfchlen']),
#  u'Neuruppiner Stra\xdfe': set([u'Neuruppiner Stra\xdfe']),
#  'Neuwerker Weg': set(['Neuwerker Weg']),
#  u'Ne\xdfstra\xdfe': set([u'Ne\xdfstra\xdfe']),
#  'Nibelungenring': set(['Nibelungenring']),
#  'Nicolaiweg': set(['Nicolaiweg']),
#  'Niederreihe': set(['Niederreihe']),
#  'Nielsenweg': set(['Nielsenweg']),
#  'Nils-Alwall-Weg': set(['Nils-Alwall-Weg']),
#  u'Nindorfer Stra\xdfe': set([u'Nindorfer Stra\xdfe']),
#  u'Noldestra\xdfe': set([u'Noldestra\xdfe']),
#  'Nordender Weg': set(['Nordender Weg']),
#  u'Norderstra\xdfe': set([u'Norderstra\xdfe']),
#  'Nordertill': set(['Nordertill']),
#  'Norderwall': set(['Norderwall']),
#  u'Nordheimstra\xdfe': set([u'Nordheimstra\xdfe']),
#  u'Nordstrander Stra\xdfe': set([u'Nordstrander Stra\xdfe']),
#  u'Nordstra\xdfe': set([u'Nordstra\xdfe']),
#  'Nordviver': set(['Nordviver']),
#  u'Normannenstra\xdfe': set([u'Normannenstra\xdfe']),
#  'Obendeich': set(['Obendeich']),
#  u'Obere B\xfcrger': set([u'Obere B\xfcrger']),
#  'Oberes Dorf': set(['Oberes Dorf']),
#  u'Oberstra\xdfe': set([u'Oberstra\xdfe']),
#  'Oberweg': set(['Oberweg']),
#  'Ochsenhammsweg': set(['Ochsenhammsweg']),
#  'Ochsenmarkt': set(['Ochsenmarkt']),
#  u'Oesterstra\xdfe': set([u'Oesterstra\xdfe']),
#  'Olekamp': set(['Olekamp']),
#  'Olen Kamp': set(['Olen Kamp']),
#  u'Ollerlohstra\xdfe': set([u'Ollerlohstra\xdfe']),
#  u'Ollnsstra\xdfe': set([u'Ollnsstra\xdfe']),
#  'Op de Lust': set(['Op de Lust']),
#  'Op de Wisch': set(['Op de Wisch']),
#  "Op'n Klint": set(["Op'n Klint"]),
#  u'Orchideenstra\xdfe': set([u'Orchideenstra\xdfe']),
#  'Ortbrookweg': set(['Ortbrookweg']),
#  'Ost': set(['Ost']),
#  'Osterberg': set(['Osterberg']),
#  u'Osterb\xfcnge-Mitte': set([u'Osterb\xfcnge-Mitte']),
#  'Osterfeld': set(['Osterfeld']),
#  'Osterjork': set(['Osterjork']),
#  u'Ostermoorer Stra\xdfe': set([u'Ostermoorer Stra\xdfe']),
#  'Osterteil': set(['Osterteil']),
#  'Ostertill': set(['Ostertill']),
#  'Ostervordels': set(['Ostervordels']),
#  'Ostlandring': set(['Ostlandring']),
#  u'Ostlandstra\xdfe': set([u'Ostlandstra\xdfe']),
#  'Ostlandweg': set(['Ostlandweg']),
#  u'Ostpreu\xdfenstra\xdfe': set([u'Ostpreu\xdfenstra\xdfe']),
#  'Ottensener Weg': set(['Ottensener Weg']),
#  u'Otto-Peschel-Stra\xdfe': set([u'Otto-Peschel-Stra\xdfe']),
#  u'Ovelg\xf6nner Weg': set([u'Ovelg\xf6nner Weg']),
#  'Palaisgarten': set(['Palaisgarten']),
#  u'Papenstra\xdfe': set([u'Papenstra\xdfe']),
#  'Pappelweg': set(['Pappelweg']),
#  u'Parkstra\xdfe': set([u'Parkstra\xdfe']),
#  'Parkweg': set(['Parkweg']),
#  u'Parna\xdfstra\xdfe': set([u'Parna\xdfstra\xdfe']),
#  u'Paul-Klee-Stra\xdfe': set([u'Paul-Klee-Stra\xdfe']),
#  u'Paul-Trede-Stra\xdfe': set([u'Paul-Trede-Stra\xdfe']),
#  'Paula-Modersohn-Becker-Weg': set(['Paula-Modersohn-Becker-Weg']),
#  'Peerkamp': set(['Peerkamp']),
#  'Pennhop': set(['Pennhop']),
#  u'Pestalozzistra\xdfe': set([u'Pestalozzistra\xdfe']),
#  u'Peter-K\xf6lln-Stra\xdfe': set([u'Peter-K\xf6lln-Stra\xdfe']),
#  u'Peterstra\xdfe': set([u'Peterstra\xdfe']),
#  'Pfahlweg': set(['Pfahlweg']),
#  'Pferdekoppel': set(['Pferdekoppel']),
#  'Philosophenweg': set(['Philosophenweg']),
#  u'Piepstra\xdfe': set([u'Piepstra\xdfe']),
#  u'Pillauer Stra\xdfe': set([u'Pillauer Stra\xdfe']),
#  'Pillauer Weg': set(['Pillauer Weg']),
#  u'Pinneberger Stra\xdfe': set([u'Pinneberger Stra\xdfe']),
#  u'Pirolstra\xdfe': set([u'Pirolstra\xdfe']),
#  u'Plinkstra\xdfe': set([u'Plinkstra\xdfe']),
#  u'Poggenbruchstra\xdfe': set([u'Poggenbruchstra\xdfe']),
#  u'Pommernstra\xdfe': set([u'Pommernstra\xdfe']),
#  u'Postbrookstra\xdfe': set([u'Postbrookstra\xdfe']),
#  'Postkamp': set(['Postkamp']),
#  u'Poststra\xdfe': set([u'Poststra\xdfe']),
#  u'Potsdamer Stra\xdfe': set([u'Potsdamer Stra\xdfe']),
#  u'Pred\xf6hlstra\xdfe': set([u'Pred\xf6hlstra\xdfe']),
#  u'Pr\xe4sident-Herwig-Stra\xdfe': set([u'Pr\xe4sident-Herwig-Stra\xdfe']),
#  'Puggenhorst': set(['Puggenhorst']),
#  u'P\xf6hlenweg': set([u'P\xf6hlenweg']),
#  'Quakenburg': set(['Quakenburg']),
#  'Quappenstieg': set(['Quappenstieg']),
#  'Querweg': set(['Querweg']),
#  u'Raboisenstra\xdfe': set([u'Raboisenstra\xdfe']),
#  u'Rahdener Stra\xdfe': set([u'Rahdener Stra\xdfe']),
#  u'Raiffeisenstra\xdfe': set([u'Raiffeisenstra\xdfe']),
#  'Rainfarnweg': set(['Rainfarnweg']),
#  'Rallenstieg': set(['Rallenstieg']),
#  'Ramskamp': set(['Ramskamp']),
#  'Rapsweg': set(['Rapsweg']),
#  'Rathausplatz': set(['Rathausplatz']),
#  u'Rathausstra\xdfe': set([u'Rathausstra\xdfe']),
#  'Reeperbahn': set(['Reeperbahn']),
#  u'Reepschl\xe4gertwiete': set([u'Reepschl\xe4gertwiete']),
#  u'Reesestra\xdfe': set([u'Reesestra\xdfe']),
#  'Rehwiese': set(['Rehwiese']),
#  u'Reichenberger Stra\xdfe': set([u'Reichenberger Stra\xdfe']),
#  'Reichenreihe': set(['Reichenreihe']),
#  'Reiherstieg': set(['Reiherstieg']),
#  'Reinhold-Maier-Weg': set(['Reinhold-Maier-Weg']),
#  'Reitbahn': set(['Reitbahn']),
#  'Rethfelder Ring': set(['Rethfelder Ring']),
#  u'Rethfelder Stra\xdfe': set([u'Rethfelder Stra\xdfe']),
#  u'Rethwischer Stra\xdfe': set([u'Rethwischer Stra\xdfe']),
#  u'Reventlowstra\xdfe': set([u'Reventlowstra\xdfe']),
#  u'Rhinstra\xdfe': set([u'Rhinstra\xdfe']),
#  u'Ringstra\xdfe': set([u'Ringstra\xdfe']),
#  u'Rissener Stra\xdfe': set([u'Rissener Stra\xdfe']),
#  u'Robbenschl\xe4gerweg': set([u'Robbenschl\xe4gerweg']),
#  'Robert-Dohrmann-Platz': set(['Robert-Dohrmann-Platz']),
#  'Roggenhof': set(['Roggenhof']),
#  'Roggenkamp': set(['Roggenkamp']),
#  u'Rohrstra\xdfe': set([u'Rohrstra\xdfe']),
#  u'Rolande-Thaumiaux-Stra\xdfe': set([u'Rolande-Thaumiaux-Stra\xdfe']),
#  'Rollberg': set(['Rollberg']),
#  'Rosengarten': set(['Rosengarten']),
#  u'Rosenstra\xdfe': set([u'Rosenstra\xdfe']),
#  'Rosenweg': set(['Rosenweg']),
#  'Rotdornallee': set(['Rotdornallee']),
#  u'Rotdornstra\xdfe': set([u'Rotdornstra\xdfe']),
#  'Rotdornweg': set(['Rotdornweg']),
#  u'Rudolf-Diesel-Stra\xdfe': set([u'Rudolf-Diesel-Stra\xdfe']),
#  'Rugenbargsweg': set(['Rugenbargsweg']),
#  'Rugenbergen': set(['Rugenbergen']),
#  u'Ruschwedeler Stra\xdfe': set([u'Ruschwedeler Stra\xdfe']),
#  u'R\xf6ntgenstra\xdfe': set([u'R\xf6ntgenstra\xdfe']),
#  u'R\xfcbezahlweg': set([u'R\xfcbezahlweg']),
#  u'R\xfcbker Stra\xdfe': set([u'R\xfcbker Stra\xdfe']),
#  u'R\xfcsternweg': set([u'R\xfcsternweg']),
#  u'R\xfcstjer Weg': set([u'R\xfcstjer Weg']),
#  u'R\xfcstringer Stra\xdfe': set([u'R\xfcstringer Stra\xdfe']),
#  u'Sachsenstra\xdfe': set([u'Sachsenstra\xdfe']),
#  'Sachsenweg': set(['Sachsenweg']),
#  u'Sackstra\xdfe': set([u'Sackstra\xdfe']),
#  'Sahlenburger Weg': set(['Sahlenburger Weg']),
#  'Salinenweg': set(['Salinenweg']),
#  'Sandberg': set(['Sandberg']),
#  'Sandersweg': set(['Sandersweg']),
#  u'Sandeskampstra\xdfe': set([u'Sandeskampstra\xdfe']),
#  u'Sandh\xf6he': set([u'Sandh\xf6he']),
#  'Sandkamp': set(['Sandkamp']),
#  'Sandkuhle': set(['Sandkuhle']),
#  'Sandweg': set(['Sandweg']),
#  u'Sankt-Laurentius-Stra\xdfe': set([u'Sankt-Laurentius-Stra\xdfe']),
#  u'Sattelmacherstra\xdfe': set([u'Sattelmacherstra\xdfe']),
#  'Schaafdrift': set(['Schaafdrift']),
#  'Schafhausenweg': set(['Schafhausenweg']),
#  'Schanze': set(['Schanze']),
#  u'Schanzenstra\xdfe': set([u'Schanzenstra\xdfe']),
#  'Schapsweide': set(['Schapsweide']),
#  u'Scharh\xf6rner Ring': set([u'Scharh\xf6rner Ring']),
#  'Schiffdorfer Chaussee': set(['Schiffdorfer Chaussee']),
#  'Schiffdorfer Grenzweg': set(['Schiffdorfer Grenzweg']),
#  'Schilfgraben': set(['Schilfgraben']),
#  u'Schillerstra\xdfe': set([u'Schillerstra\xdfe']),
#  u'Schlachthofstra\xdfe': set([u'Schlachthofstra\xdfe']),
#  'Schlangenweg': set(['Schlangenweg']),
#  'Schlesierweg': set(['Schlesierweg']),
#  u'Schleswiger Stra\xdfe': set([u'Schleswiger Stra\xdfe']),
#  'Schleuer': set(['Schleuer']),
#  'Schleuerweg': set(['Schleuerweg']),
#  'Schleuse': set(['Schleuse']),
#  u'Schleusenstra\xdfe': set([u'Schleusenstra\xdfe']),
#  u'Schlo\xdfkamp': set([u'Schlo\xdfkamp']),
#  u'Schmeelkestra\xdfe': set([u'Schmeelkestra\xdfe']),
#  'Schmidt-Isserstedt-Weg': set(['Schmidt-Isserstedt-Weg']),
#  'Schnurweg': set(['Schnurweg']),
#  u'Scholienstra\xdfe': set([u'Scholienstra\xdfe']),
#  'Schragenberg': set(['Schragenberg']),
#  u'Schr\xe4gkamp': set([u'Schr\xe4gkamp']),
#  u'Schulauer Stra\xdfe': set([u'Schulauer Stra\xdfe']),
#  'Schulkoppel': set(['Schulkoppel']),
#  u'Schulstra\xdfe': set([u'Schulstra\xdfe']),
#  'Schulweg': set(['Schulweg']),
#  u'Schumacherstra\xdfe': set([u'Schumacherstra\xdfe']),
#  'Schumannweg': set(['Schumannweg']),
#  'Schwalbenweg': set(['Schwalbenweg']),
#  'Schwangauenweg': set(['Schwangauenweg']),
#  'Schwarzer Weg': set(['Schwarzer Weg']),
#  'Schwertlilienweg': set(['Schwertlilienweg']),
#  u'Sch\xf6lischer Stra\xdfe': set([u'Sch\xf6lischer Stra\xdfe']),
#  u'Sch\xf6nb\xfctteler Teil': set([u'Sch\xf6nb\xfctteler Teil']),
#  u'Seebeckstra\xdfe': set([u'Seebeckstra\xdfe']),
#  'Seeburg': set(['Seeburg']),
#  'Seerosenring': set(['Seerosenring']),
#  u'Seerosenstra\xdfe': set([u'Seerosenstra\xdfe']),
#  'Seesteraudeich': set(['Seesteraudeich']),
#  u'Seestra\xdfe': set([u'Seestra\xdfe']),
#  u'Sellstedter Stra\xdfe': set([u'Sellstedter Stra\xdfe']),
#  'Siedenweg': set(['Siedenweg']),
#  u'Sielstra\xdfe': set([u'Sielstra\xdfe']),
#  'Siethwende': set(['Siethwende']),
#  'Siethwender Chaussee': set(['Siethwender Chaussee']),
#  u'Sietwender Stra\xdfe': set([u'Sietwender Stra\xdfe']),
#  'Sieverner See': set(['Sieverner See']),
#  u'Sieverner Stra\xdfe': set([u'Sieverner Stra\xdfe']),
#  u'Sigebandstra\xdfe': set([u'Sigebandstra\xdfe']),
#  'Slevogtweg': set(['Slevogtweg']),
#  'Soesmenhusen': set(['Soesmenhusen']),
#  'Sommerland': set(['Sommerland']),
#  'Sommerweg': set(['Sommerweg']),
#  'Sompweg': set(['Sompweg']),
#  'Sonneck': set(['Sonneck']),
#  'Sonnenweg': set(['Sonnenweg']),
#  'Spargelweg': set(['Spargelweg']),
#  'Spechtweg': set(['Spechtweg']),
#  u'Speckenstra\xdfe': set([u'Speckenstra\xdfe']),
#  'Speckenweg': set(['Speckenweg']),
#  'Speelwark Padd': set(['Speelwark Padd']),
#  'Speersort': set(['Speersort']),
#  'Spiegelberg': set(['Spiegelberg']),
#  'Spreenweg': set(['Spreenweg']),
#  'St. Pauli': set(['St. Pauli']),
#  u'Stader Stra\xdfe': set([u'Stader Stra\xdfe']),
#  u'Stadl\xe4nder Stra\xdfe': set([u'Stadl\xe4nder Stra\xdfe']),
#  u'Stargarder Stra\xdfe': set([u'Stargarder Stra\xdfe']),
#  'Stechpalmenweg': set(['Stechpalmenweg']),
#  u'Steertmoorstra\xdfe': set([u'Steertmoorstra\xdfe']),
#  'Steinberg': set(['Steinberg']),
#  'Steinberge': set(['Steinberge']),
#  u'Steinburgstra\xdfe': set([u'Steinburgstra\xdfe']),
#  'Steindeich': set(['Steindeich']),
#  'Steinhornskamp': set(['Steinhornskamp']),
#  'Steinkamp': set(['Steinkamp']),
#  u'Steink\xe4mpe': set([u'Steink\xe4mpe']),
#  u'Steinstra\xdfe': set([u'Steinstra\xdfe']),
#  u'Stettiner Stra\xdfe': set([u'Stettiner Stra\xdfe']),
#  u'Steubenstra\xdfe': set([u'Steubenstra\xdfe']),
#  u'Steudelstra\xdfe': set([u'Steudelstra\xdfe']),
#  'Stieglitzweg': set(['Stieglitzweg']),
#  u'Stockholmstra\xdfe': set([u'Stockholmstra\xdfe']),
#  u'Stolper Stra\xdfe': set([u'Stolper Stra\xdfe']),
#  'Storchenfleth': set(['Storchenfleth']),
#  'Storchenweg': set(['Storchenweg']),
#  u'Stormstra\xdfe': set([u'Stormstra\xdfe']),
#  u'Stralsunder Stra\xdfe': set([u'Stralsunder Stra\xdfe']),
#  u'Strandstra\xdfe': set([u'Strandstra\xdfe']),
#  'Strichweg': set(['Strichweg']),
#  'Strohdeich': set(['Strohdeich']),
#  'Stubbenhuk': set(['Stubbenhuk']),
#  'Stuven': set(['Stuven']),
#  u'St\xf6reck': set([u'St\xf6reck']),
#  'Sudetenweg': set(['Sudetenweg']),
#  'Swattdrosselweg': set(['Swattdrosselweg']),
#  u'S\xe4geberg': set([u'S\xe4geberg']),
#  u'S\xfcderauerdorfstra\xdfe': set([u'S\xfcderauerdorfstra\xdfe']),
#  u'S\xfcderkamp': set([u'S\xfcderkamp']),
#  u'S\xfcderstra\xdfe': set([u'S\xfcderstra\xdfe']),
#  'Tajenfeld': set(['Tajenfeld']),
#  u'Talstra\xdfe': set([u'Talstra\xdfe']),
#  u'Tannenkamper Stra\xdfe': set([u'Tannenkamper Stra\xdfe']),
#  'Tegelbreden': set(['Tegelbreden']),
#  'Teichrosenweg': set(['Teichrosenweg']),
#  u'Teichstra\xdfe': set([u'Teichstra\xdfe']),
#  'Teichweg': set(['Teichweg']),
#  u'Temmingstra\xdfe': set([u'Temmingstra\xdfe']),
#  'Tempelweg': set(['Tempelweg']),
#  u'Tetjus-T\xfcgel-Stra\xdfe': set([u'Tetjus-T\xfcgel-Stra\xdfe']),
#  u'Thekla-von-D\xfcring-Weg': set([u'Thekla-von-D\xfcring-Weg']),
#  u'Theodor-Haubach-Stra\xdfe': set([u'Theodor-Haubach-Stra\xdfe']),
#  u'Theodor-Storm-Stra\xdfe': set([u'Theodor-Storm-Stra\xdfe']),
#  u'Thomas-Mann-Stra\xdfe': set([u'Thomas-Mann-Stra\xdfe']),
#  u'Thuner M\xfchle': set([u'Thuner M\xfchle']),
#  u'Thuner Stra\xdfe': set([u'Thuner Stra\xdfe']),
#  u'Thunstra\xdfe': set([u'Thunstra\xdfe']),
#  u'Tiedemannstra\xdfe': set([u'Tiedemannstra\xdfe']),
#  u'Tilsiter Stra\xdfe': set([u'Tilsiter Stra\xdfe']),
#  'Timm Horn': set(['Timm Horn']),
#  u'Timm-Kr\xf6ger-Stra\xdfe': set([u'Timm-Kr\xf6ger-Stra\xdfe']),
#  'Tinsdaler Weg': set(['Tinsdaler Weg']),
#  u'Tondernstra\xdfe': set([u'Tondernstra\xdfe']),
#  'Torfweg': set(['Torfweg']),
#  'Tulpenweg': set(['Tulpenweg']),
#  'Twielenfleth Am Deich': set(['Twielenfleth Am Deich']),
#  'Udendorfer Teil': set(['Udendorfer Teil']),
#  u'Udonenstra\xdfe': set([u'Udonenstra\xdfe']),
#  'Uelzener Weg': set(['Uelzener Weg']),
#  'Uferweg': set(['Uferweg']),
#  u'Uhlandstra\xdfe': set([u'Uhlandstra\xdfe']),
#  'Uhlenhorst': set(['Uhlenhorst']),
#  'Uhrendorf': set(['Uhrendorf']),
#  'Ulmenweg': set(['Ulmenweg']),
#  'Unter dem Deiche': set(['Unter dem Deiche']),
#  'Utweg': set(['Utweg']),
#  u'Valger Landstra\xdfe': set([u'Valger Landstra\xdfe']),
#  u'Va\xdfmerstra\xdfe': set([u'Va\xdfmerstra\xdfe']),
#  u'Veerenholzstra\xdfe': set([u'Veerenholzstra\xdfe']),
#  u'Veerenstra\xdfe': set([u'Veerenstra\xdfe']),
#  u'Vierh\xf6fen': set([u'Vierh\xf6fen']),
#  u'Viktoriastra\xdfe': set([u'Viktoriastra\xdfe']),
#  u'Viverstra\xdfe': set([u'Viverstra\xdfe']),
#  u'Vogelbeerenstra\xdfe': set([u'Vogelbeerenstra\xdfe']),
#  'Vogelsand': set(['Vogelsand']),
#  'Volkmanns Weg': set(['Volkmanns Weg']),
#  u'Von-Aldenburg-Stra\xdfe': set([u'Von-Aldenburg-Stra\xdfe']),
#  u'Von-Aspern-Stra\xdfe': set([u'Von-Aspern-Stra\xdfe']),
#  u'Von-Graba-Stra\xdfe': set([u'Von-Graba-Stra\xdfe']),
#  u'Von-Kleist-Stra\xdfe': set([u'Von-Kleist-Stra\xdfe']),
#  u'Von-Ossietzky-Stra\xdfe': set([u'Von-Ossietzky-Stra\xdfe']),
#  u'Von-Suttner-Stra\xdfe': set([u'Von-Suttner-Stra\xdfe']),
#  'Vor dem Grevenkoper Tor': set(['Vor dem Grevenkoper Tor']),
#  u'Vorderstra\xdfe': set([u'Vorderstra\xdfe']),
#  'Vorm Dorfe': set(['Vorm Dorfe']),
#  'Vorm Moor': set(['Vorm Moor']),
#  'Vorweg': set(['Vorweg']),
#  'Vossbarg': set(['Vossbarg']),
#  'Walddrosselweg': set(['Walddrosselweg']),
#  'Waldsiedlung': set(['Waldsiedlung']),
#  u'Waldstra\xdfe': set([u'Waldstra\xdfe']),
#  'Waldweg': set(['Waldweg']),
#  u'Walf\xe4ngerweg': set([u'Walf\xe4ngerweg']),
#  u'Walkm\xfchlenstra\xdfe': set([u'Walkm\xfchlenstra\xdfe']),
#  u'Wallstra\xdfe': set([u'Wallstra\xdfe']),
#  'Wallsweg': set(['Wallsweg']),
#  u'Wangeroogestra\xdfe': set([u'Wangeroogestra\xdfe']),
#  u'Warftenstra\xdfe': set([u'Warftenstra\xdfe']),
#  u'Wartfelder Stra\xdfe': set([u'Wartfelder Stra\xdfe']),
#  u'Wasserstra\xdfe': set([u'Wasserstra\xdfe']),
#  'Wattenweg': set(['Wattenweg']),
#  u'Weberh\xf6rn': set([u'Weberh\xf6rn']),
#  u'Weberstra\xdfe': set([u'Weberstra\xdfe']),
#  u'Wehldorfer Stra\xdfe': set([u'Wehldorfer Stra\xdfe']),
#  'Weidenstieg': set(['Weidenstieg']),
#  'Weidenweg': set(['Weidenweg']),
#  u'Weimarer Stra\xdfe': set([u'Weimarer Stra\xdfe']),
#  'Weizenkamp': set(['Weizenkamp']),
#  'Welna': set(['Welna']),
#  u'Werftstra\xdfe': set([u'Werftstra\xdfe']),
#  u'Werkstra\xdfe': set([u'Werkstra\xdfe']),
#  u'Weserm\xfcnder Stra\xdfe': set([u'Weserm\xfcnder Stra\xdfe']),
#  u'Weserstra\xdfe': set([u'Weserstra\xdfe']),
#  'West': set(['West']),
#  'Westeracker': set(['Westeracker']),
#  u'Westerbeverstedter Stra\xdfe': set([u'Westerbeverstedter Stra\xdfe']),
#  u'Westerb\xfcttel': set([u'Westerb\xfcttel']),
#  'Westerjork': set(['Westerjork']),
#  'Westertweute': set(['Westertweute']),
#  'Westfleth': set(['Westfleth']),
#  'Westmoor': set(['Westmoor']),
#  u'Westpreu\xdfenweg': set([u'Westpreu\xdfenweg']),
#  'Westruck': set(['Westruck']),
#  'Wetternweg': set(['Wetternweg']),
#  u'Wichernstra\xdfe': set([u'Wichernstra\xdfe']),
#  u'Wiebeke-Kruse-Stra\xdfe': set([u'Wiebeke-Kruse-Stra\xdfe']),
#  'Wiedetwiete': set(['Wiedetwiete']),
#  u'Wiemsdorfer Dorfstra\xdfe': set([u'Wiemsdorfer Dorfstra\xdfe']),
#  'Wiesengrund': set(['Wiesengrund']),
#  u'Wiesenstra\xdfe': set([u'Wiesenstra\xdfe']),
#  'Wiesenweg': set(['Wiesenweg']),
#  'Wikingerweg': set(['Wikingerweg']),
#  u'Wilhelm-Busch-Stra\xdfe': set([u'Wilhelm-Busch-Stra\xdfe']),
#  u'Wilhelm-Ehlers-Stra\xdfe': set([u'Wilhelm-Ehlers-Stra\xdfe']),
#  'Wilhelm-Ehlers-Weg': set(['Wilhelm-Ehlers-Weg']),
#  u'Wilhelm-Heidsiek-Stra\xdfe': set([u'Wilhelm-Heidsiek-Stra\xdfe']),
#  u'Wilhelmsh\xf6he': set([u'Wilhelmsh\xf6he']),
#  u'Wilhelmstra\xdfe': set([u'Wilhelmstra\xdfe']),
#  'Wilkensweg': set(['Wilkensweg']),
#  u'Windh\xf6venweg': set([u'Windh\xf6venweg']),
#  u'Winterstra\xdfe': set([u'Winterstra\xdfe']),
#  'Wippsteertweg': set(['Wippsteertweg']),
#  'Wisch': set(['Wisch']),
#  u'Wismarer Stra\xdfe': set([u'Wismarer Stra\xdfe']),
#  'Wittsand': set(['Wittsand']),
#  'Wolterskamp': set(['Wolterskamp']),
#  'Wrangelpromenade': set(['Wrangelpromenade']),
#  'Wremer Weg': set(['Wremer Weg']),
#  u'Wulf-Isebrand-Stra\xdfe': set([u'Wulf-Isebrand-Stra\xdfe']),
#  u'Wulsdorfer Stra\xdfe': set([u'Wulsdorfer Stra\xdfe']),
#  u'Wurster Stra\xdfe': set([u'Wurster Stra\xdfe']),
#  'Zeisigweg': set(['Zeisigweg']),
#  u'Zevener Stra\xdfe': set([u'Zevener Stra\xdfe']),
#  u'Zollinlandstra\xdfe': set([u'Zollinlandstra\xdfe']),
#  u'Zu den Wohlbl\xf6cken': set([u'Zu den Wohlbl\xf6cken']),
#  'Zuckerberg': set(['Zuckerberg']),
#  'Zum Kutterhafen': set(['Zum Kutterhafen']),
#  'Zum Lunebogen': set(['Zum Lunebogen']),
#  'Zum Vorwerk': set(['Zum Vorwerk']),
#  'Zur Treppe': set(['Zur Treppe']),
#  'Zur Vilsenheide': set(['Zur Vilsenheide']),
#  u'Zur Windm\xfchle': set([u'Zur Windm\xfchle']),
#  u'\xdcber der Braake': set([u'\xdcber der Braake'])}

# %% [markdown]
# Street names in german are set together in a quite complicated way. The oficial rules are listed in this reference:
#
# https://www.duden.de/sprachwissen/rechtschreibregeln/strassennamen
#
# In  nutshell, you can expect all kind of settings, like:
# "Hauptstraße" (general case)
# "Leipziger Straße" (Leipzig is a city, causing an expection to seperate "Straße")
# "Georg-Büchner-Straße" (Georg Büchner is a person, causing an expection to use "-")
#
# To automatize a correction function to check for the applicable rule for a certain street name is very ambicious and would cetainly exceed the time related to this project.
#
# Anyhow, we can check for more obvious mistakes, like abbreviations.
# Abbreviations are in general not allowed in German Streetnames, of course with a few exceptions.
# The openstreetmap abbreviation list can be found here:
#
# https://wiki.openstreetmap.org/wiki/Name_finder:Abbreviations#Deutsch_-_German
#
# One can see that abbreviations are either followed by a "." (excepection Bhf = Bahnhof = railway station) or written in capital latters. Multiple grouped capital letters are in german only used for this purpose to my knowledge.

# %%
#Search for streetnames including "."
street_type_re = re.compile(r'\.', re.IGNORECASE)
pprint.pprint(dict(audit(OSMFILE))) # print the existing names
# Out:
# {'.': set(['Bei St. Wilhadi',
#            'I. Moorwiese',
#            'III. Sandereiweg',
#            'Neukloster Str.',
#            'St. Pauli'])}

# %%
street_type_re = re.compile(r'\b\S+\.$', re.IGNORECASE)
pprint.pprint(dict(audit(OSMFILE))) # print the existing names
# Out:
# {'Str.': set(['Neukloster Str.'])}

# %%
street_type_re = re.compile(r'Bhf')
pprint.pprint(dict(audit(OSMFILE))) # print the existing names
# Out:
# {}

# %% [markdown]
# As written above, 2 or more capital letters in a row a very unusual in german and might be caused by a mistype.

# %%
street_type_re = re.compile(r'[A-Z]{2}')
pprint.pprint(dict(audit(OSMFILE))) # print the existing names
# Out:
# {u'II': set([u'Gl\xfcckauf II', 'III. Sandereiweg']),
#  u'IV': set([u'Christian-IV-Stra\xdfe']),
#  'KI': set(['KIefhorst'])}

# %% [markdown]
# The romatic numbers are likely to be correct part of the street names. So we need to be more precise in checking for mistypes:

# %%
street_type_re = re.compile(r'[A-Z]{2}[a-z]{1}')
pprint.pprint(dict(audit(OSMFILE))) # print the existing names
# Out:
# {'KIe': set(['KIefhorst'])}

# %%
street_type_re = re.compile(r'ae')
pprint.pprint(dict(audit(OSMFILE))) # print the existing names
# Out:
# {}

# %%
#update_street = audit(OSMFILE) 
# print the updated names
#for street_type, ways in update_street.items():
#    for name in ways:
#        better_name = update_name(name, streetmapping)
#print (name, "=>", better_name)

# %%
print (update_name_german("KIefhorst",streetmapping))
# Out:
# Kiefhorst
